# %% [markdown]
# <a href="https://colab.research.google.com/github/fedor44/Sentiment_for_Stock_Investment_Strategy/blob/main/Untitled48.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Yahoo Finance에서 제공 금융 데이터 로드
import yfinance as yf

# 2023 미국주식 시가총액 순위 Top 10 (2023.05.30 기준)
# 데이터 출처 Yahoo Finance
# 금융 데이터 로드
tickers = ['AAPL','MSFT','GOOGL','AMZN','NVDA','META','TSLA', 'PEP','AVGO','ASML']
start = '2018-01-01'
end = '2023-05-31'
df_ticker_info = pd.DataFrame()
for ticker in tickers:
    ticker_yf = yf.Ticker(ticker)
    if df_ticker_info.empty:
        df_ticker_info = ticker_yf.history(start = start, end = end)
        df_ticker_info['ticker']= ticker
    else:
        data_temp = ticker_yf.history(start = start, end = end)
        data_temp['ticker']= ticker
        df_ticker_info = pd.concat([df_ticker_info, data_temp])

df_ticker_info.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2018-01-02 00:00:00-05:00  40.333818  40.841072  40.120485  40.831589
# 2018-01-03 00:00:00-05:00  40.895589  41.374400  40.760481  40.824478
# 2018-01-04 00:00:00-05:00  40.897966  41.118410  40.788932  41.014114
# 2018-01-05 00:00:00-05:00  41.111283  41.568758  41.018839  41.481056
# 2018-01-08 00:00:00-05:00  41.327003  41.625666  41.227446  41.327003
#
#                               Volume  Dividends  Stock Splits ticker
# Date
# 2018-01-02 00:00:00-05:00  102223600        0.0           0.0   AAPL
# 2018-01-03 00:00:00-05:00  118071600        0.0           0.0   AAPL
# 2018-01-04 00:00:00-05:00   89738400        0.0           0.0   AAPL
# 2018-01-05 00:00:00-05:00   94640000        0.0           0.0   AAPL
# 2018-01-08 00:00:00-05:00   82271200        0.0           0.0   AAPL

# %%
import numpy as np

# pct_change 함수를 이용, 각 날짜별 종가를 이용하여 수익률을 계산
df_ticker_info['currRet'] = df_ticker_info['Close'].pct_change()

# ticker가 바뀔 때는 정확한 수익률을 계산할 수 없으므로 첫행은 NaN 처리
temp_df_ticker_info = df_ticker_info.loc[:, 'currRet'].copy()
for i in range(len(df_ticker_info)-1):
  if df_ticker_info.iloc[i]['ticker'] != df_ticker_info.iloc[i+1]['ticker']:
    temp_df_ticker_info.iloc[i+1] = np.nan

df_ticker_info['currRet'] = temp_df_ticker_info

# 전일, 당일, 후일의 데이터를 활용하여 이벤트 수익률을 계산하여 이벤트에 따른 주가의 변동을 보다 정확하게 측정
# currRet(t-1) + currRet(t) + currRet(t+1) -> 뉴스 데이터 전일, 당일, 후일의 수익
df_ticker_info['eventRet'] = df_ticker_info['currRet'] + df_ticker_info['currRet'].shift(-1) + df_ticker_info['currRet'].shift(1)

# 날짜 (년-월-일) 정리
df_ticker_info.reset_index(inplace=True)
df_ticker_info['date'] = pd.to_datetime(df_ticker_info['Date']).dt.date

df_ticker_info.head()
# Out:
#                        Date       Open       High        Low      Close  \
# 0 2018-01-02 00:00:00-05:00  40.333818  40.841072  40.120485  40.831589
# 1 2018-01-03 00:00:00-05:00  40.895589  41.374400  40.760481  40.824478
# 2 2018-01-04 00:00:00-05:00  40.897966  41.118410  40.788932  41.014114
# 3 2018-01-05 00:00:00-05:00  41.111283  41.568758  41.018839  41.481056
# 4 2018-01-08 00:00:00-05:00  41.327003  41.625666  41.227446  41.327003
#
#       Volume  Dividends  Stock Splits ticker   currRet  eventRet        date
# 0  102223600        0.0           0.0   AAPL       NaN       NaN  2018-01-02
# 1  118071600        0.0           0.0   AAPL -0.000174       NaN  2018-01-03
# 2   89738400        0.0           0.0   AAPL  0.004645  0.015856  2018-01-04
# 3   94640000        0.0           0.0   AAPL  0.011385  0.012316  2018-01-05
# 4   82271200        0.0           0.0   AAPL -0.003714  0.007556  2018-01-08

# %%
# seekingalpha.com에서 뉴스 헤드라인 정보 스크래핑
import requests
from bs4 import BeautifulSoup
import json
from datetime import datetime
import pandas as pd

exit_flag = False
df = pd.DataFrame(columns=['ticker', 'headline', 'publishDate'])
i = 15987
tickers = ['AAPL','MSFT','GOOGL','AMZN','NVDA','META','TSLA', 'PEP','AVGO','ASML']

while True:
  # 첫번째 while 루프 페이지 번호 증가
  if exit_flag:
    break

  url = "https://seekingalpha.com/market-news"
  url = url + "?page=" + str(i)
  response = requests.get(url)
  page = requests.get(url)

  soup = BeautifulSoup(page.text, 'html.parser')
  scripts = soup.find_all('script')

  # 로드할 데이터 시간 (2018년 1월 1일까지의 데이터 로드)
  timeLimit = datetime.strptime('2018-12-31', '%Y-%m-%d')

  for j in range(0, 24):
    # 두번째 for 루프 json 내 marketNews, response, data 배열 순회

    for script in scripts:
      # 세번째 for 루프 로드된 scripts 를 라인별로 순회
      if 'window.SSR_DATA =' in script.text:
        json_data = script.text.split('window.SSR_DATA = ')[1]
        json_data = json_data[:-1]
        data = json.loads(json_data)

        headline = data['marketNews']['response']['data'][j]['attributes']['title']
        newsId = ""

        if len(data['marketNews']['response']['data'][j]['relationships']['primaryTickers']['data']) == 0:
          newsId = ""
        else:
          newsId = data['marketNews']['response']['data'][j]['relationships']['primaryTickers']['data'][0]['id']

        publishDate = data['marketNews']['response']['data'][j]['attributes']['publishOn']

        publishTime_naive = datetime.fromisoformat(publishDate)
        publishTime_naive = publishTime_naive.strftime('%Y-%m-%d %H:%M:%S')
        publishTime_naive = datetime.strptime(publishTime_naive, '%Y-%m-%d %H:%M:%S')

        if timeLimit > publishTime_naive:
          exit_flag = True
          break

        if exit_flag:
          break
        count = 0
        stock = ""
        ticker = ""
        # id 기반으로 ticker 찾기
        # Top10 항목에 포함된 주식으로만 데이터 프레임을 구축
        while True:
          if newsId == "":
            break

          if len(data['marketNews']['response']['included']) == 0:
            stock = ""
          else:
            stock = data['marketNews']['response']['included'][count]['id']

          if newsId == stock:
            ticker = data['marketNews']['response']['included'][count]['attributes']['name']
            if ticker in tickers:
              new_row = pd.DataFrame({'ticker': [ticker], 'headline': [headline], 'publishDate': [publishTime_naive]})
              df = pd.concat([df, new_row])
            break
          count = count + 1

      # 세번째 for 루프 종료

    # 두번째 for 루프 종료

  i = i + 1
  # 첫번째 while 루프 종료

df
# Out:
#   ticker                                      headline         publishDate
# 0   META        Analyst: Market needs FAANG to recover 2018-12-31 13:56:40
# 0   TSLA         Tesla still with plenty of inventory? 2018-12-31 10:42:17
# 0   AMZN             Amazon targets rural India market 2018-12-31 09:35:36
# 0   AAPL          Epic Games takes on Apple and Google 2018-12-31 09:04:14
# 0  GOOGL  Bloomberg: Self-driving cars "down the road" 2018-12-31 08:17:46
# 0   AMZN      Amazon plans to expand Whole Foods reach 2018-12-31 02:45:05

# %%
# 뉴스 헤드라인 정보를 스크래핑하는데 10시간 이상의 시간이 소요 됨
# 끊어서 헤드라인 정보를 로드하고 csv 파일(news.csv)로 만들어 병합한 뒤 google drive에 저장하여 사용
from google.colab import drive
drive.mount('/content/drive/')
import pandas as pd

df_news = pd.read_csv('/content/drive/MyDrive/DeepNeuralNetwork/news.csv')

df_news

# 날짜 (년-월-일) 정리
df_news['date'] = pd.to_datetime(df_news['publishDate']).dt.date

# df_news 에 df_ticker_info 를 left 조인
df_mergedData = pd.merge(df_news, df_ticker_info, how='left', left_on=['date','ticker'], right_on=['date','ticker'])

# 필요한 데이터만 남기고 정리
df_finalData = df_mergedData[['ticker','headline','date','eventRet','Close']]

# NaN 이 있는 행 드롭
df_finalData = df_finalData.dropna()

# 모델 분석 시 편리하게 사용하기 위하여 전처리 된 정보 csv 파일로 저장
df_finalData.to_csv('/content/drive/MyDrive/DeepNeuralNetwork/finalData.csv')

df_finalData.head()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#    ticker                                           headline        date  \
# 28   META  Meta gains as 'scrappier' company looks to piv...  2023-05-26
# 29   MSFT  Microsoft developer conference seen as positiv...  2023-05-26
# 30   TSLA  Tesla may be under scrutiny in Europe for data...  2023-05-25
# 31   NVDA  Nvidia soars 25% as chips rally on 'jaw droppi...  2023-05-25
# 32   NVDA  Inside Nvidia: AI drives record data center re...  2023-05-25
#
#     eventRet       Close
# 28  0.052798  262.040009
# 29  0.054797  332.890015
# 30  0.040297  184.470001
# 31  0.264243  379.760681
# 32  0.264243  379.760681

# %%
# 자연어 처리, 문장 분류, 개체 인식, 감정 분석, 질문 응답 등의 작업을 처리할 수 있는 SpaCy에서 제공하는 en_core_web_lg 모델 설치
#!python -m spacy download en_core_web_lg

import pandas as pd
import en_core_web_lg
nlp = en_core_web_lg.load()

# 감정 분석에 어떤 모델을 이용할지 여러 알고리즘을 이용하여 확인
# kaggle에서 모델 확인에 필요한 감정 데이터가 레이블링 된 데이터를 로드 함
# (https://www.kaggle.com/datasets/ryanchan911/selective-stock-headlines-sentiment?select=Project6500.csv)
# 해당 데이터를 다운 받아 구글 드라이드에 저장하여 사용
df_sentimentData = pd.read_csv('/content/drive/MyDrive/DeepNeuralNetwork/Project6500.csv', encoding='ISO-8859-1')

# 로드 된 값의 모든 headline에 대해 단어 벡터 평균을 계산
# 해당 평균 벡터는 각 문장의 의미를 임베딩(벡터 공간으로 표현)하는데 사용 됨
vectors = pd.np.array([pd.np.array([token.vector for token in nlp(s)]).mean(axis=0) * pd.np.ones((300)) \
                           for s in df_sentimentData['headline']])
# Out:
# 2023-06-14 08:38:50.198878: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.5.0/en_core_web_lg-3.5.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.5.0) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.1.2)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# <ipython-input-4-56cc9bdcb7c5>:16: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   vectors = pd.np.array([pd.np.array([token.vector for token in nlp(s)]).mean(axis=0) * pd.np.ones((300)) \

# %%
# 모델 선정을 위한 각종 라이브러리 로드
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# 데이터프레임의 "sentiment" 컬럼을 타겟 변수로 지정하여 변수 Y에 할당
Y= df_sentimentData["sentiment"]
# vectors 변수를 독립 변수로 지정하여 변수 X에 할당
X = vectors

validation_size = 0.3
seed = 7
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = validation_size, random_state = seed)

# 모델 평가를 위한 옵션 설정
num_folds = 10
seed = 7
scoring = 'accuracy'

# 분류 모델 설정
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('SVM', SVC()))
models.append(('NN', MLPClassifier()))
models.append(('RF', RandomForestClassifier()))

results = []
names = []
kfold_results = []
test_results = []
train_results = []
for name, model in models:
  # 모델 교차 검증 준비
  kfold = KFold(n_splits=num_folds, random_state = seed, shuffle=True)
  # 교차 검증을 통한 모델 평가
  cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
  results.append(cv_results)
  names.append(name)

  # 전체 학습 및 테스트를 통한 모델 평가
  res = model.fit(X_train, Y_train)
  # 학습 데이터에 대한 예측 결과를 평가하여 학습 정확도를 계산
  train_result = accuracy_score(res.predict(X_train), Y_train)
  train_results.append(train_result)
  # 테스트 데이터에 대한 예측 결과를 평가하여 테스트 정확도를 계산
  test_result = accuracy_score(res.predict(X_test), Y_test)
  test_results.append(test_result)

  # 모델 이름, 교차 검증 평균 정확도, 교차 검증 정확도의 표준 편차, 학습 정확도, 테스트 정확도
  msg = "%s: %f (%f) %f %f" % (name, cv_results.mean(), cv_results.std(), train_result, test_result)
  print(msg)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LR: 0.872982 (0.006606) 0.893951 0.870468
# KNN: 0.759392 (0.013987) 0.848243 0.763816
# CART: 0.693771 (0.021180) 0.999698 0.686378
# SVM: 0.831200 (0.015621) 0.862875 0.833861
# NN: 0.898024 (0.008871) 0.999246 0.910595
# RF: 0.789864 (0.012250) 0.999698 0.788103

# %%
import numpy as np
# 바 그래프를 이용한 결과 비교
from matplotlib import pyplot

fig = pyplot.figure()
ind = np.arange(len(names))
width = 0.3
fig.suptitle('Comparison of model result')
ax = fig.add_subplot(111)
pyplot.bar(ind - width/2, train_results,  width = width, label = 'Train Results', color = 'royalblue')
pyplot.bar(ind + width/2, test_results, width = width, label = 'Test Results', color = 'skyblue')
fig.set_size_inches(10,6)
pyplot.legend()
ax.set_xticks(ind)
ax.set_xticklabels(names)
pyplot.show()

# %%
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# LSTM을 이용한 감정 분석 시도
vocabulary_size = 20000
tokenizer = Tokenizer(num_words= vocabulary_size)
tokenizer.fit_on_texts(df_sentimentData['headline'])
sequences = tokenizer.texts_to_sequences(df_sentimentData['headline'])

# LSTM 모델의 입력 값 설정
X_LSTM = pad_sequences(sequences, maxlen=50)
Y_LSTM = df_sentimentData["sentiment"]

X_train_LSTM, X_test_LSTM, Y_train_LSTM, Y_test_LSTM = train_test_split(X_LSTM, Y_LSTM, test_size = validation_size, random_state = seed)

# LSTM 관련 라이브러리 추가
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense

# LSTM 모델을 생성
def create_model(input_length=50):
    model = Sequential()
    model.add(Embedding(20000, 300, input_length=50))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# LSTM 모델 훈련
model_LSTM = KerasClassifier(build_fn = create_model, epochs = 3, verbose = 1, validation_split = 0.4)
model_LSTM.fit(X_train_LSTM, Y_train_LSTM)
# Out:
# <ipython-input-8-623666ef2446>:35: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model_LSTM = KerasClassifier(build_fn = create_model, epochs = 3, verbose = 1, validation_split = 0.4)
# Epoch 1/3
# 125/125 [==============================] - 50s 364ms/step - loss: 0.3465 - accuracy: 0.8371 - val_loss: 0.1005 - val_accuracy: 0.9664
# Epoch 2/3
# 125/125 [==============================] - 34s 274ms/step - loss: 0.0426 - accuracy: 0.9877 - val_loss: 0.1217 - val_accuracy: 0.9544
# Epoch 3/3
# 125/125 [==============================] - 39s 312ms/step - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.0820 - val_accuracy: 0.9736

# %%
# LSTM 훈련 결과 평가
train_result_LSTM = accuracy_score(model_LSTM.predict(X_train_LSTM), Y_train_LSTM)
test_result_LSTM = accuracy_score(model_LSTM.predict(X_test_LSTM), Y_test_LSTM)

print(train_result_LSTM,test_result_LSTM)
# Out:
# 208/208 [==============================] - 4s 19ms/step
# 89/89 [==============================] - 2s 18ms/step
# 0.9880826670689395 0.9736008447729673

# %%
# LSTM 데이터 추가 후 그래프 출력
train_results.append(train_result_LSTM)
test_results.append(test_result_LSTM)
names.append("LSTM")

import numpy as np
# 바 그래프를 이용한 결과 비교
from matplotlib import pyplot

fig = pyplot.figure()
ind = np.arange(len(names))
width = 0.3
fig.suptitle('Comparison of model result')
ax = fig.add_subplot(111)
pyplot.bar(ind - width/2, train_results, width = width, label = 'Train Results', color = 'royalblue')
pyplot.bar(ind + width/2, test_results, width = width, label = 'Test Results', color = 'skyblue')
fig.set_size_inches(10,6)
pyplot.legend()
ax.set_xticks(ind)
ax.set_xticklabels(names)
pyplot.show()

# %%
# 위 차트를 보면 LSTM 모델의 결과가 가장 좋기 때문에 기존에 만들어 놓은 데이터를 기반으로 LSTM을 이용해 감정 분석 시도
import pandas as pd

# 감정 분석을 위해 기존에 전처리 해놓았던 데이터(seeking alpha 에서 얻은 헤드라인 정보와 수익률을 계산하여 저장) 로드
df_finalData = pd.read_csv('/content/drive/MyDrive/DeepNeuralNetwork/finalData.csv')

# 기존에 학습시켜 놓았던 LSTM 모델을 사용해 감정 분석 시도
sequences = tokenizer.texts_to_sequences(df_finalData['headline'])
X_LSTM = pad_sequences(sequences, maxlen=50)
Y_LSTM = model_LSTM.predict(X_LSTM)

# LSTM 을 이용하여 감정 분석한 결과 저장
df_finalData['sentiment_LSTM'] = Y_LSTM
# Out:
# 274/274 [==============================] - 8s 30ms/step

# %%
# 감정 분석을 위해 nltk의 vader 모델을 사용하기 위해 패키지 다운로드
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
import pandas as pd

# VADER 모델에서 사용 할 어휘 리소스를 github 에서 다운로드
# 어휘 리소스 출처 (https://github.com/nunomroliveira/stock_market_lexicon)
# 해당 어휘 리소스는 통계 측정 및 레이블이 지정된 대규모 메시지셋을 사용해 자동으로 생성되었음
# Stock market sentiment lexicon acquisition using microblogging data and statistical measures 논문 참고
# 논문 출처 (https://repositorium.sdum.uminho.pt/bitstream/1822/42367/1/paper.pdf)
df_lexicon = pd.read_csv('https://raw.githubusercontent.com/nunomroliveira/stock_market_lexicon/master/stock_lex.csv')

# 다운로드 된 어휘 리소스는 구글 드라이브에 저장
df_lexicon.to_csv('/content/drive/MyDrive/DeepNeuralNetwork/lexiconData.csv')

df_lexicon
# Out:
#                 Item  POS  Aff_Score  Neg_Score
# 0                'em   PR   0.379542   0.533419
# 1                 'n   CC   1.413176   1.199917
# 2          'n handle  NaN   2.839000   2.941000
# 3               's a  NaN  -0.023077  -0.013615
# 4             's abc  NaN   2.261667   2.300000
# ...              ...  ...        ...        ...
# 20545           zoom   VB  -0.652273  -0.649174
# 20546  zortrades.com   NN   2.141000   2.163000
# 20547            zte   NN   4.934000   5.084000
# 20548           zuck   NN  -0.237857  -0.185172
# 20549     zuckerberg   NN  -0.309667  -0.236923
#
# [20550 rows x 4 columns]

# %%
import pandas as pd

# 감정 분석 수행
sia = SentimentIntensityAnalyzer()
df_lexicon = pd.read_csv('/content/drive/MyDrive/DeepNeuralNetwork/lexiconData.csv')
# 두 열의 값을 더하고 평균 내어 각 어휘의 감정 점수를 계산
df_lexicon['sentiment'] = (df_lexicon['Aff_Score'] + df_lexicon['Neg_Score'])/2
# Item 열을 키(key)로, sentiment 열을 값(value)으로 갖는 딕셔너리로 변환
df_lexicon = dict(zip(df_lexicon.Item, df_lexicon.sentiment))
# 하나의 단어로 구성된 항목만을 선택하여 딕셔너리 업데이트
df_lexicon = {k:v for k,v in df_lexicon.items() if len(k.split(' '))==1}
temp_dict = {}

# value 조건에 value 값 재계산 후 딕셔너리에 추가
for k, v in df_lexicon.items():
  if v > 0:
    temp_dict[k] = v / max(df_lexicon.values()) * 4
  else:
    temp_dict[k] = v / min(df_lexicon.values()) * -4

final_dict = {}
# 딕셔너리에 주식 시장 관련 어휘와 감정 점수 업데이트
final_dict.update(temp_dict)
# 딕셔너리에 sia.lexicon의 어휘와 감정 점수 업데이트
final_dict.update(sia.lexicon)
# 하나의 딕셔너리로 결합된 정보를 sia.lexicon에 할당
# 주식 시장 관련 어휘와 기존의 감정 어휘를 모두 활용하여 감정 점수 계산 가능
sia.lexicon = final_dict

# %%
# vader 모델을 이용하여 감성 지수 계산
sentiment_vader = pd.np.array([sia.polarity_scores(s)['compound'] for s in df_finalData['headline']])
df_finalData['sentiment_vader'] = sentiment_vader

# 감정 지표가 추가된 데이터 구글 드라이브에 저장
df_finalData.to_csv('/content/drive/MyDrive/DeepNeuralNetwork/finalData.csv')
# Out:
# <ipython-input-7-2b9eb02d7b90>:4: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   sentiment_vader = pd.np.array([sia.polarity_scores(s)['compound'] for s in df_finalData['headline']])

# %%
import matplotlib.pyplot as plt

# 특정 주식에 대한 감정 지표와 이벤트 수익률 간의 관계를 산점도로 시각화 (VADER)
ticker_info = df_finalData[df_finalData['ticker'] == 'AMZN']
plt.scatter(ticker_info['sentiment_vader'],ticker_info['eventRet'], alpha=0.5)
plt.title('Scatter Between Event and sentiments (AMZN)')
plt.ylabel('Event Return')
plt.xlabel('Sentiments')
plt.show()
# 이벤트 수익률과 감정 지표 사이에는 양의 상관 관계가 있음을 확인할 수 있음

# %%
# 특정 주식에 대한 감정 지표와 이벤트 수익률 간의 관계를 산점도로 시각화 (LSTM)
ticker_info = df_finalData[df_finalData['ticker'] == 'AMZN']
plt.scatter(ticker_info['sentiment_LSTM'],ticker_info['eventRet'], alpha=0.5)
plt.title('Scatter Between Event and sentiments (AMZN)')
plt.ylabel('Event Return')
plt.xlabel('Sentiments')
plt.show()
# 이벤트 수익률과 감정 지표 사이의 관계를 확인하기 어려움 (LSTM은 감정 지표를 0과 1로 표현)

# %%
# 특정 주식에 대해 히트맵을 그려 상관 관계가 좋은 모델을 선택
import seaborn as sns

df_ticker = df_finalData[df_finalData['ticker']== 'AMZN'][['ticker','headline', 'sentiment_LSTM','sentiment_vader', 'eventRet']]
correlation = df_ticker[['sentiment_LSTM','sentiment_vader','eventRet']].dropna(axis=0).corr()

plt.figure(figsize=(5,5))
plt.title('Correlation Matrix (AMZN)')
sns.heatmap(correlation[['eventRet']], vmax=1, annot=True,cmap='cubehelix')
# 히트맵 확인 시 수익률 예측은 vader > LSTM 으로 확인됨
# Out:
# <Axes: title={'center': 'Correlation Matrix (AMZN)'}>

# %%
# 수익률과 LSTM, vader 와의 상관 관계 계산 후 그래프로 표시
corr_data = []
for ticker in df_finalData['ticker'].unique():
  ticker_data = df_finalData[df_finalData['ticker'] == ticker]
  if ticker_data.shape[0] > 40 :
    corr_LSTM = ticker_data['eventRet'].corr(ticker_data['sentiment_LSTM'])
    corr_vader = ticker_data['eventRet'].corr(ticker_data['sentiment_vader'])
    corr_data.append([ticker, corr_LSTM, corr_vader])
  else:
    continue

df_corr = pd.DataFrame(corr_data, columns = ['ticker', 'corr_LSTM', 'corr_vader'])
df_corr = df_corr.set_index('ticker')

tickers = ['AAPL','MSFT','GOOGL','AMZN','NVDA','META','TSLA', 'PEP','AVGO','ASML']
df_corr.loc[tickers].plot.bar(figsize = (8, 7))
plt.show()
# 각 ticker의 상관 관계를 살펴보면 확실히 vader쪽이 높음

# %%
# 전략 백테스트와 알고리즘 주식 거래를 위한 backtrader 설치
# !pip install backtrader

import backtrader as bt
import backtrader.indicators as btind
import backtrader.analyzers as btanalyzers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting backtrader
#   Downloading backtrader-1.9.78.123-py2.py3-none-any.whl (419 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: backtrader
# Successfully installed backtrader-1.9.78.123

# %%
# Backtrader에서 사용되는 사용자 정의 지표
# https://www.backtrader.com/docu/quickstart/quickstart/ 예제 참고
# 아래 클래스 필요한지 확인 필요
class Sentiment(bt.Indicator):
  lines = ('sentiment',)
  plot_info = dict(plotymargin=0.5, plothlines=[0], plotyticks=[1.0, 0, -1.0])

  def next(self):
    self.sentiment = 0.0
    self.date = self.data.datetime
    date = bt.num2date(self.date[0]).date()
    prev_sentiment = self.sentiment
    if date in date_sentiment:
      self.sentiment = date_sentiment[date]
      self.lines.sentiment[0] = self.sentiment

# %%
# 거래 전략 구현 클래스
class Strategy(bt.Strategy):
  # 이동 평균 기간과 로그 사용 여부 변수
  params = (('period', 20), ('printlog', True), )

  # 로그 함수
  def log(self, txt, dt = None, doprint = False):
    ''' Logging function for this strategy'''
    if self.params.printlog or doprint:
      dt = dt or self.datas[0].datetime.date(0)
      print('%s, %s' % (dt.isoformat(), txt))

  # 초기화
  def __init__(self):
    # 종가 참조
    # Keep a reference to the "close" line in the data[0] dataseries
    self.dataclose = self.datas[0].close
    # 각 변수 초기화
    # To keep track of pending orders and buy price/commission
    self.order = None
    self.buyprice = None
    self.buycomm = None
    # 이동 평균 사용(20일 기준)
    # Add a MovingAverageSimple indicator
    self.sma = bt.indicators.SimpleMovingAverage(self.datas[0], period=self.params.period)
    self.date = self.data.datetime
    self.sentiment = None
    Sentiment(self.data)
    self.plotinfo.plot = False

  # 주문의 상태 변화를 처리하기 위한 함수
  def notify_order(self, order):
    if order.status in [order.Submitted, order.Accepted]:
      # Buy/Sell order submitted/accepted to/by broker - Nothing to do
      return

    # Check if an order has been completed
    # Attention: broker could reject order if not enough cash
    if order.status in [order.Completed]:
      # 매수 주문
      if order.isbuy():
        self.log('BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                 (order.executed.price,
                  order.executed.value,
                  order.executed.comm))
        self.buyprice = order.executed.price
        self.buycomm = order.executed.comm
      # 매도 주문
      else:
        self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                 (order.executed.price,
                  order.executed.value,
                  order.executed.comm))

      self.bar_executed = len(self)

    elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

    # Write down: no pending order
    self.order = None

  # 거래의 상태 변화 처리
  def notify_trade(self, trade):
    if not trade.isclosed:
      return

    self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
              (trade.pnl, trade.pnlcomm))

  # 메인 전략 함수
  ### Main Strat ###
  def next(self):
    date = bt.num2date(self.date[0]).date()
    prev_sentiment = self.sentiment
    if date in date_sentiment:
      self.sentiment = date_sentiment[date]

    # Check if an order is pending. if yes, we cannot send a 2nd one
    if self.order:
      return

    # 로드된 감정지수(prev_sentiment)가 있다면 조건에 맞추어 매수 및 매도 주문을 생성
    if not self.position and prev_sentiment:
      # 현재 종가(dataclose)가 단순 이동평균(sma)보다 크고, 감정지수의 변화량이 0.5 이상이면 매수 주문 생성
      if self.dataclose[0] > self.sma[0] and self.sentiment - prev_sentiment >= 0.5:
        self.log('Previous Sentiment %.2f, New Sentiment %.2f BUY CREATE, %.2f' %
         (prev_sentiment, self.sentiment, self.dataclose[0]))
        self.order = self.buy()

    elif prev_sentiment:
      # 현재 종가(dataclose)가 단순 이동평균(sma)보다 작고, 감정지수의 변화량이 -0.5 이하이면 매도 주문 생성
      if self.dataclose[0] < self.sma[0] and self.sentiment - prev_sentiment <= -0.5:
        self.log('Previous Sentiment %.2f, New Sentiment %.2f SELL CREATE, %.2f' %
                 (prev_sentiment, self.sentiment, self.dataclose[0]))
        self.order = self.sell()

  # 전략 실행이 종료될 때 호출
  # 현재 포트폴리오의 최종 가치 출력
  def stop(self):
    self.log('(MA Period %2d) Ending Value %.2f' % (self.params.period, self.broker.getvalue()), doprint=True)

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# 전략 실행
# 특정 주식에 대해 전략을 실행하고 결과 출력
# 10만 달러로 시작, 100주씩 거래
def run_strategy(ticker, start, end):
  print(ticker)
  ticker = yf.Ticker(ticker)
  df_ticker = ticker.history(start = start, end = end)

  # Create a cerebro entity
  cerebro = bt.Cerebro()
  # Add a strategy
  cerebro.addstrategy(Strategy)
  data = bt.feeds.PandasData(dataname=df_ticker)
  # Add the Data Feed to Cerebro
  cerebro.adddata(data)
  # Set our desired cash start
  start = 100000.0
  cerebro.broker.setcash(start)
  cerebro.addsizer(bt.sizers.FixedSize, stake=100)
  print('Starting Portfolio Value: %.2f' % start)
  plt.rcParams['figure.figsize']=[10,6]
  plt.rcParams["font.size"]="12"
  cerebro.run()
  cerebro.plot(volume=False, iplot=True, plotname= ticker)
  end = cerebro.broker.getvalue()
  print('Start Portfolio value: %.2f\nFinal Portfolio Value: %.2f\nProfit: %.2f\n' % (start, end, end - start))
  chart_file = 'chartResult.png'
  cerebro.plot()[0][0].savefig(chart_file, dpi=300)
  return float(df_ticker['Close'][0]), (end - start)

# %%
import pandas as pd
from IPython.display import Image

# 감정 지표가 추가된 데이터 구글 드라이브에 저장
df_finalData = pd.read_csv('/content/drive/MyDrive/DeepNeuralNetwork/finalData.csv')

# 감정 지표를 이용해 특정 주식에 대한 전략 실행
ticker = 'MSFT'
date_sentiment = df_finalData[df_finalData['ticker'].isin([ticker])]
date_sentiment = date_sentiment[['date','sentiment_vader']]
date_sentiment['date'] = pd.to_datetime(date_sentiment['date'], format='%Y-%m-%d').dt.date
date_sentiment = date_sentiment.set_index('date')['sentiment_vader']
date_sentiment = date_sentiment.to_dict()

run_strategy(ticker, start = '2018-01-01', end = '2023-05-31')

Image(open('chartResult.png', 'rb').read())
# Out:
# MSFT
# Starting Portfolio Value: 100000.00
# 2018-02-26, Previous Sentiment -0.03, New Sentiment 0.76 BUY CREATE, 89.86
# 2018-02-27, BUY EXECUTED, Price: 90.16, Cost: 9015.99, Comm 0.00
# 2018-03-29, Previous Sentiment 0.74, New Sentiment 0.05 SELL CREATE, 85.95
# 2018-04-02, SELL EXECUTED, Price: 85.20, Cost: 9015.99, Comm 0.00
# 2018-04-02, OPERATION PROFIT, GROSS -496.29, NET -496.29
# 2018-04-10, Previous Sentiment -0.10, New Sentiment 0.61 BUY CREATE, 87.47
# 2018-04-11, BUY EXECUTED, Price: 86.65, Cost: 8664.73, Comm 0.00
# 2018-06-25, Previous Sentiment 0.48, New Sentiment -0.04 SELL CREATE, 93.06
# 2018-06-26, SELL EXECUTED, Price: 93.46, Cost: 8664.73, Comm 0.00
# 2018-06-26, OPERATION PROFIT, GROSS 681.64, NET 681.64
# 2018-07-10, Previous Sentiment -0.32, New Sentiment 0.58 BUY CREATE, 96.58
# 2018-07-11, BUY EXECUTED, Price: 95.67, Cost: 9566.74, Comm 0.00
# 2018-12-20, Previous Sentiment 0.67, New Sentiment -0.17 SELL CREATE, 96.79
# 2018-12-21, SELL EXECUTED, Price: 96.91, Cost: 9566.74, Comm 0.00
# 2018-12-21, OPERATION PROFIT, GROSS 124.07, NET 124.07
# 2019-01-18, Previous Sentiment -0.14, New Sentiment 0.51 BUY CREATE, 102.71
# 2019-01-22, BUY EXECUTED, Price: 101.79, Cost: 10179.03, Comm 0.00
# 2020-02-27, Previous Sentiment 0.64, New Sentiment 0.11 SELL CREATE, 153.48
# 2020-02-28, SELL EXECUTED, Price: 147.88, Cost: 10179.03, Comm 0.00
# 2020-02-28, OPERATION PROFIT, GROSS 4609.03, NET 4609.03
# 2020-04-06, Previous Sentiment -0.32, New Sentiment 0.33 BUY CREATE, 160.36
# 2020-04-07, BUY EXECUTED, Price: 164.55, Cost: 16455.00, Comm 0.00
# 2020-09-08, Previous Sentiment 0.44, New Sentiment -0.23 SELL CREATE, 197.66
# 2020-09-09, SELL EXECUTED, Price: 202.48, Cost: 16455.00, Comm 0.00
# 2020-09-09, OPERATION PROFIT, GROSS 3792.96, NET 3792.96
# 2020-10-01, Previous Sentiment -0.64, New Sentiment -0.03 BUY CREATE, 207.22
# 2020-10-02, BUY EXECUTED, Price: 202.87, Cost: 20286.98, Comm 0.00
# 2021-02-22, Previous Sentiment 0.42, New Sentiment -0.22 SELL CREATE, 229.85
# 2021-02-23, SELL EXECUTED, Price: 225.76, Cost: 20286.98, Comm 0.00
# 2021-02-23, OPERATION PROFIT, GROSS 2288.62, NET 2288.62
# 2021-04-01, Previous Sentiment 0.03, New Sentiment 0.70 BUY CREATE, 237.54
# 2021-04-05, BUY EXECUTED, Price: 237.94, Cost: 23793.91, Comm 0.00
# 2021-05-07, Previous Sentiment 0.81, New Sentiment -0.29 SELL CREATE, 247.45
# 2021-05-10, SELL EXECUTED, Price: 245.89, Cost: 23793.91, Comm 0.00
# 2021-05-10, OPERATION PROFIT, GROSS 794.89, NET 794.89
# 2021-05-28, Previous Sentiment -0.54, New Sentiment -0.01 BUY CREATE, 245.29
# 2021-06-01, BUY EXECUTED, Price: 246.81, Cost: 24680.95, Comm 0.00
# 2022-01-20, Previous Sentiment 0.24, New Sentiment -0.63 SELL CREATE, 297.40
# 2022-01-21, SELL EXECUTED, Price: 298.48, Cost: 24680.95, Comm 0.00
# 2022-01-21, OPERATION PROFIT, GROSS 5166.89, NET 5166.89
# 2022-02-08, Previous Sentiment -0.01, New Sentiment 0.65 BUY CREATE, 300.32
# 2022-02-09, BUY EXECUTED, Price: 305.56, Cost: 30555.85, Comm 0.00
# 2022-03-04, Previous Sentiment 0.20, New Sentiment -0.36 SELL CREATE, 286.42
# 2022-03-07, SELL EXECUTED, Price: 285.10, Cost: 30555.85, Comm 0.00
# 2022-03-07, OPERATION PROFIT, GROSS -2045.48, NET -2045.48
# 2022-07-11, Previous Sentiment -0.46, New Sentiment 0.12 BUY CREATE, 261.98
# 2022-07-12, BUY EXECUTED, Price: 263.33, Cost: 26333.46, Comm 0.00
# 2022-07-19, Previous Sentiment 0.76, New Sentiment 0.18 SELL CREATE, 257.05
# 2022-07-20, SELL EXECUTED, Price: 257.41, Cost: 26333.46, Comm 0.00
# 2022-07-20, OPERATION PROFIT, GROSS -592.28, NET -592.28
# 2022-11-28, Previous Sentiment -0.30, New Sentiment 0.23 BUY CREATE, 240.63
# 2022-11-29, BUY EXECUTED, Price: 240.27, Cost: 24027.16, Comm 0.00
# 2023-02-23, Previous Sentiment 0.45, New Sentiment -0.22 SELL CREATE, 254.21
# 2023-02-24, SELL EXECUTED, Price: 249.41, Cost: 24027.16, Comm 0.00
# 2023-02-24, OPERATION PROFIT, GROSS 914.31, NET 914.31
# 2023-04-03, Previous Sentiment -0.70, New Sentiment 0.59 BUY CREATE, 286.60
# 2023-04-04, BUY EXECUTED, Price: 286.60, Cost: 28660.35, Comm 0.00
# 2023-05-30, (MA Period 20) Ending Value 119699.03
# <div id='24e693bc-2dd7-40e4-87a2-8de363b75543'></div>
# Start Portfolio value: 100000.00
# Final Portfolio Value: 119699.03
# Profit: 19699.03

# %%
# 감정 지표를 기반으로 전체 주식에 대해 투자 후 수익 확인
all_tickers = {}
tickers = ['AAPL','MSFT','GOOGL','AMZN','NVDA','META','TSLA', 'PEP','AVGO','ASML']

for ticker in tickers:
  date_sentiment = df_finalData[df_finalData['ticker'].isin([ticker])]
  date_sentiment = date_sentiment[['date','sentiment_vader']]
  date_sentiment['date'] = pd.to_datetime(date_sentiment['date'], format='%Y-%m-%d').dt.date
  date_sentiment = date_sentiment.set_index('date')['sentiment_vader']
  date_sentiment = date_sentiment.to_dict()
  all_tickers[ticker] = run_strategy(ticker, start = '2018-01-01', end = '2023-05-31')
# Out:
# <ipython-input-6-7d5dbcf9ec56>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   date_sentiment['date'] = pd.to_datetime(date_sentiment['date'], format='%Y-%m-%d').dt.date
# AAPL
# Starting Portfolio Value: 100000.00
# 2018-02-14, Previous Sentiment -0.40, New Sentiment 0.43 BUY CREATE, 39.83
# 2018-02-15, BUY EXECUTED, Price: 40.41, Cost: 4041.02, Comm 0.00
# 2018-03-21, Previous Sentiment 0.11, New Sentiment -0.50 SELL CREATE, 40.76
# 2018-03-22, SELL EXECUTED, Price: 40.46, Cost: 4041.02, Comm 0.00
# 2018-03-22, OPERATION PROFIT, GROSS 5.00, NET 5.00
# 2018-05-16, Previous Sentiment -0.06, New Sentiment 0.49 BUY CREATE, 44.96
# 2018-05-17, BUY EXECUTED, Price: 44.92, Cost: 4491.67, Comm 0.00
# 2018-06-19, Previous Sentiment 0.85, New Sentiment 0.15 SELL CREATE, 44.36
# 2018-06-20, SELL EXECUTED, Price: 44.52, Cost: 4491.67, Comm 0.00
# 2018-06-20, OPERATION PROFIT, GROSS -39.42, NET -39.42
# 2018-07-12, Previous Sentiment -0.14, New Sentiment 0.51 BUY CREATE, 45.64
# 2018-07-13, BUY EXECUTED, Price: 45.65, Cost: 4565.26, Comm 0.00
# 2018-09-10, Previous Sentiment 0.60, New Sentiment -0.03 SELL CREATE, 52.35
# 2018-09-11, SELL EXECUTED, Price: 52.27, Cost: 4565.26, Comm 0.00
# 2018-09-11, OPERATION PROFIT, GROSS 661.68, NET 661.68
# 2018-09-11, Previous Sentiment -0.03, New Sentiment 0.56 BUY CREATE, 53.67
# 2018-09-12, BUY EXECUTED, Price: 53.93, Cost: 5393.09, Comm 0.00
# 2018-09-26, Previous Sentiment 0.49, New Sentiment -0.35 SELL CREATE, 52.85
# 2018-09-27, SELL EXECUTED, Price: 53.66, Cost: 5393.09, Comm 0.00
# 2018-09-27, OPERATION PROFIT, GROSS -26.85, NET -26.85
# 2018-10-09, Previous Sentiment -0.10, New Sentiment 0.73 BUY CREATE, 54.39
# 2018-10-10, BUY EXECUTED, Price: 54.06, Cost: 5405.56, Comm 0.00
# 2018-10-10, Previous Sentiment 0.73, New Sentiment 0.08 SELL CREATE, 51.87
# 2018-10-11, SELL EXECUTED, Price: 51.43, Cost: 5405.56, Comm 0.00
# 2018-10-11, OPERATION PROFIT, GROSS -262.29, NET -262.29
# 2019-02-21, Previous Sentiment -0.26, New Sentiment 0.76 BUY CREATE, 41.33
# 2019-02-22, BUY EXECUTED, Price: 41.46, Cost: 4145.80, Comm 0.00
# 2019-05-14, Previous Sentiment 0.85, New Sentiment 0.17 SELL CREATE, 45.76
# 2019-05-15, SELL EXECUTED, Price: 45.18, Cost: 4145.80, Comm 0.00
# 2019-05-15, OPERATION PROFIT, GROSS 372.28, NET 372.28
# 2019-06-19, Previous Sentiment -0.17, New Sentiment 0.37 BUY CREATE, 47.99
# 2019-06-20, BUY EXECUTED, Price: 48.60, Cost: 4860.09, Comm 0.00
# 2019-08-05, Previous Sentiment 0.37, New Sentiment -0.75 SELL CREATE, 46.90
# 2019-08-06, SELL EXECUTED, Price: 47.62, Cost: 4860.09, Comm 0.00
# 2019-08-06, OPERATION PROFIT, GROSS -98.48, NET -98.48
# 2019-08-13, Previous Sentiment -0.41, New Sentiment 0.65 BUY CREATE, 50.88
# 2019-08-14, BUY EXECUTED, Price: 49.46, Cost: 4946.48, Comm 0.00
# 2019-08-14, Previous Sentiment 0.65, New Sentiment -0.28 SELL CREATE, 49.37
# 2019-08-15, SELL EXECUTED, Price: 49.54, Cost: 4946.48, Comm 0.00
# 2019-08-15, OPERATION PROFIT, GROSS 7.30, NET 7.30
# 2019-08-26, Previous Sentiment 0.00, New Sentiment 0.61 BUY CREATE, 50.28
# 2019-08-27, BUY EXECUTED, Price: 50.61, Cost: 5060.92, Comm 0.00
# 2020-02-03, Previous Sentiment 0.60, New Sentiment -0.19 SELL CREATE, 75.38
# 2020-02-04, SELL EXECUTED, Price: 77.00, Cost: 5060.92, Comm 0.00
# 2020-02-04, OPERATION PROFIT, GROSS 2639.21, NET 2639.21
# 2020-02-11, Previous Sentiment -0.35, New Sentiment 0.30 BUY CREATE, 78.24
# 2020-02-12, BUY EXECUTED, Price: 78.69, Cost: 7869.19, Comm 0.00
# 2020-03-06, Previous Sentiment 0.31, New Sentiment -0.47 SELL CREATE, 70.75
# 2020-03-09, SELL EXECUTED, Price: 64.56, Cost: 7869.19, Comm 0.00
# 2020-03-09, OPERATION PROFIT, GROSS -1412.92, NET -1412.92
# 2020-04-13, Previous Sentiment -0.12, New Sentiment 0.46 BUY CREATE, 66.89
# 2020-04-14, BUY EXECUTED, Price: 68.54, Cost: 6854.06, Comm 0.00
# 2020-07-24, Previous Sentiment 0.32, New Sentiment -0.36 SELL CREATE, 90.93
# 2020-07-27, SELL EXECUTED, Price: 92.00, Cost: 6854.06, Comm 0.00
# 2020-07-27, OPERATION PROFIT, GROSS 2346.41, NET 2346.41
# 2020-07-27, Previous Sentiment -0.36, New Sentiment 0.21 BUY CREATE, 93.08
# 2020-07-28, BUY EXECUTED, Price: 92.65, Cost: 9265.02, Comm 0.00
# 2020-09-08, Previous Sentiment 0.31, New Sentiment -0.22 SELL CREATE, 110.97
# 2020-09-09, SELL EXECUTED, Price: 115.33, Cost: 9265.02, Comm 0.00
# 2020-09-09, OPERATION PROFIT, GROSS 2268.35, NET 2268.35
# 2020-10-07, Previous Sentiment 0.16, New Sentiment 0.75 BUY CREATE, 113.19
# 2020-10-08, BUY EXECUTED, Price: 114.34, Cost: 11434.02, Comm 0.00
# 2020-11-25, Previous Sentiment 0.22, New Sentiment -0.74 SELL CREATE, 114.32
# 2020-11-27, SELL EXECUTED, Price: 114.85, Cost: 11434.02, Comm 0.00
# 2020-11-27, OPERATION PROFIT, GROSS 51.25, NET 51.25
# 2020-11-27, Previous Sentiment -0.74, New Sentiment 0.61 BUY CREATE, 114.87
# 2020-11-30, BUY EXECUTED, Price: 115.25, Cost: 11524.69, Comm 0.00
# 2021-01-06, Previous Sentiment 0.78, New Sentiment 0.25 SELL CREATE, 124.74
# 2021-01-07, SELL EXECUTED, Price: 126.47, Cost: 11524.69, Comm 0.00
# 2021-01-07, OPERATION PROFIT, GROSS 1122.22, NET 1122.22
# 2021-01-27, Previous Sentiment -0.01, New Sentiment 0.78 BUY CREATE, 139.97
# 2021-01-28, BUY EXECUTED, Price: 137.46, Cost: 13746.47, Comm 0.00
# 2021-02-17, Previous Sentiment 0.30, New Sentiment -0.49 SELL CREATE, 129.11
# 2021-02-18, SELL EXECUTED, Price: 127.49, Cost: 13746.47, Comm 0.00
# 2021-02-18, OPERATION PROFIT, GROSS -997.78, NET -997.78
# 2021-04-26, Previous Sentiment -0.58, New Sentiment 0.67 BUY CREATE, 132.93
# 2021-04-27, BUY EXECUTED, Price: 133.22, Cost: 13321.99, Comm 0.00
# 2021-04-30, Previous Sentiment 0.33, New Sentiment -0.42 SELL CREATE, 129.72
# 2021-05-03, SELL EXECUTED, Price: 130.29, Cost: 13321.99, Comm 0.00
# 2021-05-03, OPERATION PROFIT, GROSS -293.06, NET -293.06
# 2021-06-14, Previous Sentiment -0.08, New Sentiment 0.43 BUY CREATE, 128.97
# 2021-06-15, BUY EXECUTED, Price: 128.43, Cost: 12843.49, Comm 0.00
# 2021-09-16, Previous Sentiment 0.69, New Sentiment 0.06 SELL CREATE, 147.29
# 2021-09-17, SELL EXECUTED, Price: 147.32, Cost: 12843.49, Comm 0.00
# 2021-09-17, OPERATION PROFIT, GROSS 1888.17, NET 1888.17
# 2021-11-01, Previous Sentiment -0.22, New Sentiment 0.35 BUY CREATE, 147.46
# 2021-11-02, BUY EXECUTED, Price: 147.16, Cost: 14715.83, Comm 0.00
# 2022-02-22, Previous Sentiment 0.90, New Sentiment 0.23 SELL CREATE, 163.10
# 2022-02-23, SELL EXECUTED, Price: 164.32, Cost: 14715.83, Comm 0.00
# 2022-02-23, OPERATION PROFIT, GROSS 1715.77, NET 1715.77
# 2022-03-28, Previous Sentiment -0.40, New Sentiment 0.78 BUY CREATE, 174.30
# 2022-03-29, BUY EXECUTED, Price: 175.38, Cost: 17538.35, Comm 0.00
# 2022-04-13, Previous Sentiment 0.70, New Sentiment 0.09 SELL CREATE, 169.14
# 2022-04-14, SELL EXECUTED, Price: 169.36, Cost: 17538.35, Comm 0.00
# 2022-04-14, OPERATION PROFIT, GROSS -602.51, NET -602.51
# 2022-06-06, Previous Sentiment -0.17, New Sentiment 0.67 BUY CREATE, 145.27
# 2022-06-07, BUY EXECUTED, Price: 143.49, Cost: 14349.32, Comm 0.00
# 2022-06-13, Previous Sentiment 0.53, New Sentiment -0.47 SELL CREATE, 131.10
# 2022-06-14, SELL EXECUTED, Price: 132.34, Cost: 14349.32, Comm 0.00
# 2022-06-14, OPERATION PROFIT, GROSS -1115.34, NET -1115.34
# 2022-06-27, Previous Sentiment 0.04, New Sentiment 0.72 BUY CREATE, 140.82
# 2022-06-28, BUY EXECUTED, Price: 141.29, Cost: 14128.64, Comm 0.00
# 2022-06-28, Previous Sentiment 0.72, New Sentiment -0.76 SELL CREATE, 136.62
# 2022-06-29, SELL EXECUTED, Price: 136.64, Cost: 14128.64, Comm 0.00
# 2022-06-29, OPERATION PROFIT, GROSS -464.23, NET -464.23
# 2022-07-06, Previous Sentiment -0.05, New Sentiment 0.59 BUY CREATE, 142.07
# 2022-07-07, BUY EXECUTED, Price: 142.44, Cost: 14243.95, Comm 0.00
# 2022-08-29, Previous Sentiment 0.63, New Sentiment -0.08 SELL CREATE, 160.64
# 2022-08-30, SELL EXECUTED, Price: 161.39, Cost: 14243.95, Comm 0.00
# 2022-08-30, OPERATION PROFIT, GROSS 1895.20, NET 1895.20
# 2022-10-28, Previous Sentiment 0.09, New Sentiment 0.65 BUY CREATE, 155.03
# 2022-10-31, BUY EXECUTED, Price: 152.46, Cost: 15246.24, Comm 0.00
# 2022-11-08, Previous Sentiment 0.28, New Sentiment -0.33 SELL CREATE, 139.09
# 2022-11-09, SELL EXECUTED, Price: 138.10, Cost: 15246.24, Comm 0.00
# 2022-11-09, OPERATION PROFIT, GROSS -1436.45, NET -1436.45
# 2022-12-05, Previous Sentiment -0.05, New Sentiment 0.47 BUY CREATE, 146.20
# 2022-12-06, BUY EXECUTED, Price: 146.64, Cost: 14664.30, Comm 0.00
# 2022-12-13, Previous Sentiment 0.75, New Sentiment 0.15 SELL CREATE, 145.05
# 2022-12-14, SELL EXECUTED, Price: 144.93, Cost: 14664.30, Comm 0.00
# 2022-12-14, OPERATION PROFIT, GROSS -171.50, NET -171.50
# 2023-01-17, Previous Sentiment 0.05, New Sentiment 0.79 BUY CREATE, 135.55
# 2023-01-18, BUY EXECUTED, Price: 136.42, Cost: 13642.27, Comm 0.00
# 2023-05-30, (MA Period 20) Ending Value 112139.74
# Start Portfolio value: 100000.00
# Final Portfolio Value: 112139.74
# Profit: 12139.74
#
# MSFT
# Starting Portfolio Value: 100000.00
# 2018-02-26, Previous Sentiment -0.03, New Sentiment 0.76 BUY CREATE, 89.86
# 2018-02-27, BUY EXECUTED, Price: 90.16, Cost: 9015.99, Comm 0.00
# 2018-03-29, Previous Sentiment 0.74, New Sentiment 0.05 SELL CREATE, 85.95
# 2018-04-02, SELL EXECUTED, Price: 85.20, Cost: 9015.99, Comm 0.00
# 2018-04-02, OPERATION PROFIT, GROSS -496.29, NET -496.29
# 2018-04-10, Previous Sentiment -0.10, New Sentiment 0.61 BUY CREATE, 87.47
# 2018-04-11, BUY EXECUTED, Price: 86.65, Cost: 8664.73, Comm 0.00
# 2018-06-25, Previous Sentiment 0.48, New Sentiment -0.04 SELL CREATE, 93.06
# 2018-06-26, SELL EXECUTED, Price: 93.46, Cost: 8664.73, Comm 0.00
# 2018-06-26, OPERATION PROFIT, GROSS 681.64, NET 681.64
# 2018-07-10, Previous Sentiment -0.32, New Sentiment 0.58 BUY CREATE, 96.58
# 2018-07-11, BUY EXECUTED, Price: 95.67, Cost: 9566.75, Comm 0.00
# 2018-12-20, Previous Sentiment 0.67, New Sentiment -0.17 SELL CREATE, 96.79
# 2018-12-21, SELL EXECUTED, Price: 96.91, Cost: 9566.75, Comm 0.00
# 2018-12-21, OPERATION PROFIT, GROSS 124.07, NET 124.07
# 2019-01-18, Previous Sentiment -0.14, New Sentiment 0.51 BUY CREATE, 102.71
# 2019-01-22, BUY EXECUTED, Price: 101.79, Cost: 10179.03, Comm 0.00
# 2020-02-27, Previous Sentiment 0.64, New Sentiment 0.11 SELL CREATE, 153.48
# 2020-02-28, SELL EXECUTED, Price: 147.88, Cost: 10179.03, Comm 0.00
# 2020-02-28, OPERATION PROFIT, GROSS 4609.03, NET 4609.03
# 2020-04-06, Previous Sentiment -0.32, New Sentiment 0.33 BUY CREATE, 160.36
# 2020-04-07, BUY EXECUTED, Price: 164.55, Cost: 16455.00, Comm 0.00
# 2020-09-08, Previous Sentiment 0.44, New Sentiment -0.23 SELL CREATE, 197.66
# 2020-09-09, SELL EXECUTED, Price: 202.48, Cost: 16455.00, Comm 0.00
# 2020-09-09, OPERATION PROFIT, GROSS 3792.97, NET 3792.97
# 2020-10-01, Previous Sentiment -0.64, New Sentiment -0.03 BUY CREATE, 207.22
# 2020-10-02, BUY EXECUTED, Price: 202.87, Cost: 20286.98, Comm 0.00
# 2021-02-22, Previous Sentiment 0.42, New Sentiment -0.22 SELL CREATE, 229.85
# 2021-02-23, SELL EXECUTED, Price: 225.76, Cost: 20286.98, Comm 0.00
# 2021-02-23, OPERATION PROFIT, GROSS 2288.61, NET 2288.61
# 2021-04-01, Previous Sentiment 0.03, New Sentiment 0.70 BUY CREATE, 237.54
# 2021-04-05, BUY EXECUTED, Price: 237.94, Cost: 23793.91, Comm 0.00
# 2021-05-07, Previous Sentiment 0.81, New Sentiment -0.29 SELL CREATE, 247.45
# 2021-05-10, SELL EXECUTED, Price: 245.89, Cost: 23793.91, Comm 0.00
# 2021-05-10, OPERATION PROFIT, GROSS 794.89, NET 794.89
# 2021-05-28, Previous Sentiment -0.54, New Sentiment -0.01 BUY CREATE, 245.29
# 2021-06-01, BUY EXECUTED, Price: 246.81, Cost: 24680.95, Comm 0.00
# 2022-01-20, Previous Sentiment 0.24, New Sentiment -0.63 SELL CREATE, 297.40
# 2022-01-21, SELL EXECUTED, Price: 298.48, Cost: 24680.95, Comm 0.00
# 2022-01-21, OPERATION PROFIT, GROSS 5166.89, NET 5166.89
# 2022-02-08, Previous Sentiment -0.01, New Sentiment 0.65 BUY CREATE, 300.32
# 2022-02-09, BUY EXECUTED, Price: 305.56, Cost: 30555.84, Comm 0.00
# 2022-03-04, Previous Sentiment 0.20, New Sentiment -0.36 SELL CREATE, 286.42
# 2022-03-07, SELL EXECUTED, Price: 285.10, Cost: 30555.84, Comm 0.00
# 2022-03-07, OPERATION PROFIT, GROSS -2045.48, NET -2045.48
# 2022-07-11, Previous Sentiment -0.46, New Sentiment 0.12 BUY CREATE, 261.98
# 2022-07-12, BUY EXECUTED, Price: 263.33, Cost: 26333.46, Comm 0.00
# 2022-07-19, Previous Sentiment 0.76, New Sentiment 0.18 SELL CREATE, 257.05
# 2022-07-20, SELL EXECUTED, Price: 257.41, Cost: 26333.46, Comm 0.00
# 2022-07-20, OPERATION PROFIT, GROSS -592.28, NET -592.28
# 2022-11-28, Previous Sentiment -0.30, New Sentiment 0.23 BUY CREATE, 240.63
# 2022-11-29, BUY EXECUTED, Price: 240.27, Cost: 24027.16, Comm 0.00
# 2023-02-23, Previous Sentiment 0.45, New Sentiment -0.22 SELL CREATE, 254.21
# 2023-02-24, SELL EXECUTED, Price: 249.41, Cost: 24027.16, Comm 0.00
# 2023-02-24, OPERATION PROFIT, GROSS 914.31, NET 914.31
# 2023-04-03, Previous Sentiment -0.70, New Sentiment 0.59 BUY CREATE, 286.60
# 2023-04-04, BUY EXECUTED, Price: 286.60, Cost: 28660.35, Comm 0.00
# 2023-05-30, (MA Period 20) Ending Value 119699.04
# Start Portfolio value: 100000.00
# Final Portfolio Value: 119699.04
# Profit: 19699.04
#
# GOOGL
# Starting Portfolio Value: 100000.00
# 2018-08-14, Previous Sentiment -0.55, New Sentiment 0.27 BUY CREATE, 62.91
# 2018-08-15, BUY EXECUTED, Price: 62.21, Cost: 6221.40, Comm 0.00
# 2021-05-14, Previous Sentiment 0.30, New Sentiment -0.25 SELL CREATE, 113.92
# 2021-05-17, SELL EXECUTED, Price: 113.18, Cost: 6221.40, Comm 0.00
# 2021-05-17, OPERATION PROFIT, GROSS 5096.45, NET 5096.45
# 2021-06-24, Previous Sentiment -0.32, New Sentiment 0.23 BUY CREATE, 122.50
# 2021-06-25, BUY EXECUTED, Price: 122.00, Cost: 12200.00, Comm 0.00
# 2021-09-24, Previous Sentiment 0.59, New Sentiment -0.40 SELL CREATE, 142.21
# 2021-09-27, SELL EXECUTED, Price: 140.80, Cost: 12200.00, Comm 0.00
# 2021-09-27, OPERATION PROFIT, GROSS 1880.45, NET 1880.45
# 2023-02-07, Previous Sentiment -0.04, New Sentiment 0.53 BUY CREATE, 107.64
# 2023-02-08, BUY EXECUTED, Price: 102.05, Cost: 10205.00, Comm 0.00
# 2023-02-14, Previous Sentiment 0.61, New Sentiment -0.10 SELL CREATE, 94.68
# 2023-02-15, SELL EXECUTED, Price: 94.49, Cost: 10205.00, Comm 0.00
# 2023-02-15, OPERATION PROFIT, GROSS -756.00, NET -756.00
# 2023-03-29, Previous Sentiment -0.04, New Sentiment 0.73 BUY CREATE, 101.39
# 2023-03-30, BUY EXECUTED, Price: 100.91, Cost: 10091.00, Comm 0.00
# 2023-05-30, (MA Period 20) Ending Value 108496.90
# Start Portfolio value: 100000.00
# Final Portfolio Value: 108496.90
# Profit: 8496.90
#
# AMZN
# Starting Portfolio Value: 100000.00
# 2018-02-14, Previous Sentiment -0.05, New Sentiment 0.55 BUY CREATE, 72.55
# 2018-02-15, BUY EXECUTED, Price: 73.34, Cost: 7334.45, Comm 0.00
# 2018-03-28, Previous Sentiment 0.43, New Sentiment -0.15 SELL CREATE, 71.57
# 2018-03-29, SELL EXECUTED, Price: 70.30, Cost: 7334.45, Comm 0.00
# 2018-03-29, OPERATION PROFIT, GROSS -304.45, NET -304.45
# 2018-05-03, Previous Sentiment 0.11, New Sentiment 0.78 BUY CREATE, 78.60
# 2018-05-04, BUY EXECUTED, Price: 78.12, Cost: 7812.25, Comm 0.00
# 2018-10-09, Previous Sentiment 0.37, New Sentiment -0.21 SELL CREATE, 93.52
# 2018-10-10, SELL EXECUTED, Price: 92.89, Cost: 7812.25, Comm 0.00
# 2018-10-10, OPERATION PROFIT, GROSS 1477.20, NET 1477.20
# 2018-11-08, Previous Sentiment 0.17, New Sentiment 0.70 BUY CREATE, 87.75
# 2018-11-09, BUY EXECUTED, Price: 86.62, Cost: 8662.50, Comm 0.00
# 2018-11-15, Previous Sentiment 0.32, New Sentiment -0.39 SELL CREATE, 80.97
# 2018-11-16, SELL EXECUTED, Price: 79.38, Cost: 8662.50, Comm 0.00
# 2018-11-16, OPERATION PROFIT, GROSS -725.00, NET -725.00
# 2018-12-06, Previous Sentiment -0.19, New Sentiment 0.53 BUY CREATE, 84.96
# 2018-12-07, BUY EXECUTED, Price: 85.25, Cost: 8525.35, Comm 0.00
# 2018-12-20, Previous Sentiment 0.62, New Sentiment -0.08 SELL CREATE, 73.04
# 2018-12-21, SELL EXECUTED, Price: 73.25, Cost: 8525.35, Comm 0.00
# 2018-12-21, OPERATION PROFIT, GROSS -1200.40, NET -1200.40
# 2019-01-04, Previous Sentiment -0.15, New Sentiment 0.46 BUY CREATE, 78.77
# 2019-01-07, BUY EXECUTED, Price: 80.12, Cost: 8011.55, Comm 0.00
# 2019-05-17, Previous Sentiment 0.43, New Sentiment -0.15 SELL CREATE, 93.45
# 2019-05-20, SELL EXECUTED, Price: 92.63, Cost: 8011.55, Comm 0.00
# 2019-05-20, OPERATION PROFIT, GROSS 1251.90, NET 1251.90
# 2019-06-10, Previous Sentiment 0.12, New Sentiment 0.70 BUY CREATE, 93.03
# 2019-06-11, BUY EXECUTED, Price: 94.16, Cost: 9416.25, Comm 0.00
# 2019-08-19, Previous Sentiment 0.28, New Sentiment -0.31 SELL CREATE, 90.81
# 2019-08-20, SELL EXECUTED, Price: 90.72, Cost: 9416.25, Comm 0.00
# 2019-08-20, OPERATION PROFIT, GROSS -343.75, NET -343.75
# 2019-12-17, Previous Sentiment 0.17, New Sentiment 0.71 BUY CREATE, 89.53
# 2019-12-18, BUY EXECUTED, Price: 89.75, Cost: 8975.10, Comm 0.00
# 2020-01-24, Previous Sentiment 0.48, New Sentiment -0.62 SELL CREATE, 93.08
# 2020-01-27, SELL EXECUTED, Price: 91.00, Cost: 8975.10, Comm 0.00
# 2020-01-27, OPERATION PROFIT, GROSS 124.90, NET 124.90
# 2020-04-16, Previous Sentiment -0.37, New Sentiment 0.47 BUY CREATE, 120.41
# 2020-04-17, BUY EXECUTED, Price: 118.62, Cost: 11861.65, Comm 0.00
# 2020-05-12, Previous Sentiment 0.04, New Sentiment -0.54 SELL CREATE, 117.85
# 2020-05-13, SELL EXECUTED, Price: 118.34, Cost: 11861.65, Comm 0.00
# 2020-05-13, OPERATION PROFIT, GROSS -27.65, NET -27.65
# 2020-05-19, Previous Sentiment -0.73, New Sentiment -0.02 BUY CREATE, 122.47
# 2020-05-20, BUY EXECUTED, Price: 123.89, Cost: 12389.35, Comm 0.00
# 2020-11-10, Previous Sentiment 0.85, New Sentiment -0.24 SELL CREATE, 151.75
# 2020-11-11, SELL EXECUTED, Price: 153.09, Cost: 12389.35, Comm 0.00
# 2020-11-11, OPERATION PROFIT, GROSS 2919.55, NET 2919.55
# 2020-12-01, Previous Sentiment -0.09, New Sentiment 0.60 BUY CREATE, 161.00
# 2020-12-02, BUY EXECUTED, Price: 161.08, Cost: 16108.25, Comm 0.00
# 2021-03-11, Previous Sentiment 0.88, New Sentiment 0.13 SELL CREATE, 155.68
# 2021-03-12, SELL EXECUTED, Price: 153.75, Cost: 16108.25, Comm 0.00
# 2021-03-12, OPERATION PROFIT, GROSS -733.25, NET -733.25
# 2021-03-17, Previous Sentiment -0.00, New Sentiment 0.81 BUY CREATE, 156.79
# 2021-03-18, BUY EXECUTED, Price: 155.05, Cost: 15505.00, Comm 0.00
# 2021-05-17, Previous Sentiment 0.42, New Sentiment -0.12 SELL CREATE, 163.52
# 2021-05-18, SELL EXECUTED, Price: 164.63, Cost: 15505.00, Comm 0.00
# 2021-05-18, OPERATION PROFIT, GROSS 957.90, NET 957.90
# 2021-06-18, Previous Sentiment -0.22, New Sentiment 0.43 BUY CREATE, 174.35
# 2021-06-21, BUY EXECUTED, Price: 173.82, Cost: 17382.10, Comm 0.00
# 2021-08-04, Previous Sentiment 0.83, New Sentiment 0.13 SELL CREATE, 167.74
# 2021-08-05, SELL EXECUTED, Price: 167.81, Cost: 17382.10, Comm 0.00
# 2021-08-05, OPERATION PROFIT, GROSS -601.00, NET -601.00
# 2021-09-15, Previous Sentiment 0.29, New Sentiment 0.88 BUY CREATE, 173.79
# 2021-09-16, BUY EXECUTED, Price: 173.00, Cost: 17299.80, Comm 0.00
# 2021-10-04, Previous Sentiment 0.63, New Sentiment 0.11 SELL CREATE, 159.49
# 2021-10-05, SELL EXECUTED, Price: 160.23, Cost: 17299.80, Comm 0.00
# 2021-10-05, OPERATION PROFIT, GROSS -1277.30, NET -1277.30
# 2021-10-29, Previous Sentiment -0.54, New Sentiment 0.76 BUY CREATE, 168.62
# 2021-11-01, BUY EXECUTED, Price: 168.09, Cost: 16809.00, Comm 0.00
# 2021-12-08, Previous Sentiment 0.37, New Sentiment -0.48 SELL CREATE, 176.16
# 2021-12-09, SELL EXECUTED, Price: 175.75, Cost: 16809.00, Comm 0.00
# 2021-12-09, OPERATION PROFIT, GROSS 766.00, NET 766.00
# 2022-02-04, Previous Sentiment 0.06, New Sentiment 0.66 BUY CREATE, 157.64
# 2022-02-07, BUY EXECUTED, Price: 158.52, Cost: 15852.00, Comm 0.00
# 2022-03-09, Previous Sentiment 0.46, New Sentiment -0.45 SELL CREATE, 139.28
# 2022-03-10, SELL EXECUTED, Price: 145.68, Cost: 15852.00, Comm 0.00
# 2022-03-10, OPERATION PROFIT, GROSS -1283.50, NET -1283.50
# 2022-03-17, Previous Sentiment -0.28, New Sentiment 0.35 BUY CREATE, 157.24
# 2022-03-18, BUY EXECUTED, Price: 156.81, Cost: 15681.30, Comm 0.00
# 2022-04-27, Previous Sentiment 0.43, New Sentiment -0.51 SELL CREATE, 138.17
# 2022-04-28, SELL EXECUTED, Price: 142.18, Cost: 15681.30, Comm 0.00
# 2022-04-28, OPERATION PROFIT, GROSS -1463.50, NET -1463.50
# 2022-08-04, Previous Sentiment -0.22, New Sentiment 0.66 BUY CREATE, 142.57
# 2022-08-05, BUY EXECUTED, Price: 140.10, Cost: 14010.00, Comm 0.00
# 2022-09-16, Previous Sentiment 0.44, New Sentiment -0.33 SELL CREATE, 123.53
# 2022-09-19, SELL EXECUTED, Price: 122.16, Cost: 14010.00, Comm 0.00
# 2022-09-19, OPERATION PROFIT, GROSS -1794.00, NET -1794.00
# 2023-01-19, Previous Sentiment -0.61, New Sentiment 0.19 BUY CREATE, 93.68
# 2023-01-20, BUY EXECUTED, Price: 93.86, Cost: 9386.00, Comm 0.00
# 2023-05-30, (MA Period 20) Ending Value 100523.65
# Start Portfolio value: 100000.00
# Final Portfolio Value: 100523.65
# Profit: 523.65
#
# NVDA
# Starting Portfolio Value: 100000.00
# 2018-06-18, Previous Sentiment -0.25, New Sentiment 0.28 BUY CREATE, 65.67
# 2018-06-19, BUY EXECUTED, Price: 64.63, Cost: 6463.43, Comm 0.00
# 2018-09-21, Previous Sentiment 0.13, New Sentiment -0.38 SELL CREATE, 65.30
# 2018-09-24, SELL EXECUTED, Price: 64.99, Cost: 6463.43, Comm 0.00
# 2018-09-24, OPERATION PROFIT, GROSS 35.26, NET 35.26
# 2019-01-07, Previous Sentiment -0.40, New Sentiment 0.43 BUY CREATE, 35.58
# 2019-01-08, BUY EXECUTED, Price: 36.39, Cost: 3639.38, Comm 0.00
# 2019-01-28, Previous Sentiment 0.46, New Sentiment -0.23 SELL CREATE, 34.24
# 2019-01-29, SELL EXECUTED, Price: 33.78, Cost: 3639.38, Comm 0.00
# 2019-01-29, OPERATION PROFIT, GROSS -261.50, NET -261.50
# 2019-02-22, Previous Sentiment 0.05, New Sentiment 0.56 BUY CREATE, 39.50
# 2019-02-25, BUY EXECUTED, Price: 40.33, Cost: 4033.12, Comm 0.00
# 2019-05-16, Previous Sentiment 0.62, New Sentiment 0.11 SELL CREATE, 39.78
# 2019-05-17, SELL EXECUTED, Price: 39.36, Cost: 4033.12, Comm 0.00
# 2019-05-17, OPERATION PROFIT, GROSS -96.68, NET -96.68
# 2019-06-13, Previous Sentiment -0.69, New Sentiment 0.37 BUY CREATE, 36.86
# 2019-06-14, BUY EXECUTED, Price: 35.93, Cost: 3593.09, Comm 0.00
# 2019-11-15, Previous Sentiment 0.74, New Sentiment -0.03 SELL CREATE, 50.82
# 2019-11-18, SELL EXECUTED, Price: 50.75, Cost: 3593.09, Comm 0.00
# 2019-11-18, OPERATION PROFIT, GROSS 1481.44, NET 1481.44
# 2019-12-16, Previous Sentiment -0.21, New Sentiment 0.62 BUY CREATE, 56.08
# 2019-12-17, BUY EXECUTED, Price: 56.26, Cost: 5626.47, Comm 0.00
# 2020-02-25, Previous Sentiment 0.52, New Sentiment -0.48 SELL CREATE, 65.27
# 2020-02-26, SELL EXECUTED, Price: 65.27, Cost: 5626.47, Comm 0.00
# 2020-02-26, OPERATION PROFIT, GROSS 900.64, NET 900.64
# 2020-03-02, Previous Sentiment -0.48, New Sentiment 0.51 BUY CREATE, 68.89
# 2020-03-03, BUY EXECUTED, Price: 69.45, Cost: 6944.97, Comm 0.00
# 2020-03-06, Previous Sentiment 0.51, New Sentiment 0.00 SELL CREATE, 66.30
# 2020-03-09, SELL EXECUTED, Price: 59.79, Cost: 6944.97, Comm 0.00
# 2020-03-09, OPERATION PROFIT, GROSS -966.22, NET -966.22
# 2020-06-23, Previous Sentiment 0.01, New Sentiment 0.58 BUY CREATE, 94.25
# 2020-06-24, BUY EXECUTED, Price: 94.51, Cost: 9450.93, Comm 0.00
# 2021-03-15, Previous Sentiment 0.27, New Sentiment -0.31 SELL CREATE, 131.68
# 2021-03-16, SELL EXECUTED, Price: 133.33, Cost: 9450.93, Comm 0.00
# 2021-03-16, OPERATION PROFIT, GROSS 3882.40, NET 3882.40
# 2021-03-23, Previous Sentiment -0.31, New Sentiment 0.60 BUY CREATE, 130.48
# 2021-03-24, BUY EXECUTED, Price: 131.28, Cost: 13128.44, Comm 0.00
# 2021-05-18, Previous Sentiment 0.71, New Sentiment -0.01 SELL CREATE, 139.91
# 2021-05-19, SELL EXECUTED, Price: 135.43, Cost: 13128.44, Comm 0.00
# 2021-05-19, OPERATION PROFIT, GROSS 414.53, NET 414.53
# 2021-06-22, Previous Sentiment -0.14, New Sentiment 0.78 BUY CREATE, 188.58
# 2021-06-23, BUY EXECUTED, Price: 189.79, Cost: 18979.13, Comm 0.00
# 2021-10-06, Previous Sentiment 0.80, New Sentiment -0.04 SELL CREATE, 206.72
# 2021-10-07, SELL EXECUTED, Price: 210.64, Cost: 18979.13, Comm 0.00
# 2021-10-07, OPERATION PROFIT, GROSS 2084.82, NET 2084.82
# 2021-10-22, Previous Sentiment -0.23, New Sentiment 0.50 BUY CREATE, 226.96
# 2021-10-25, BUY EXECUTED, Price: 229.42, Cost: 22942.46, Comm 0.00
# 2021-12-03, Previous Sentiment 0.46, New Sentiment -0.08 SELL CREATE, 306.56
# 2021-12-06, SELL EXECUTED, Price: 298.44, Cost: 22942.46, Comm 0.00
# 2021-12-06, OPERATION PROFIT, GROSS 6901.47, NET 6901.47
# 2022-03-18, Previous Sentiment -0.59, New Sentiment 0.66 BUY CREATE, 264.26
# 2022-03-21, BUY EXECUTED, Price: 264.80, Cost: 26479.52, Comm 0.00
# 2022-04-08, Previous Sentiment 0.77, New Sentiment -0.15 SELL CREATE, 230.95
# 2022-04-11, SELL EXECUTED, Price: 221.91, Cost: 26479.52, Comm 0.00
# 2022-04-11, OPERATION PROFIT, GROSS -4288.55, NET -4288.55
# 2022-06-01, Previous Sentiment -0.59, New Sentiment 0.36 BUY CREATE, 183.01
# 2022-06-02, BUY EXECUTED, Price: 182.73, Cost: 18273.03, Comm 0.00
# 2022-06-29, Previous Sentiment 0.16, New Sentiment -0.76 SELL CREATE, 155.29
# 2022-06-30, SELL EXECUTED, Price: 153.48, Cost: 18273.03, Comm 0.00
# 2022-06-30, OPERATION PROFIT, GROSS -2924.72, NET -2924.72
# 2022-10-04, Previous Sentiment -0.67, New Sentiment 0.04 BUY CREATE, 131.60
# 2022-10-05, BUY EXECUTED, Price: 129.04, Cost: 12904.17, Comm 0.00
# 2023-02-21, Previous Sentiment 0.86, New Sentiment 0.07 SELL CREATE, 206.49
# 2023-02-22, SELL EXECUTED, Price: 207.01, Cost: 12904.17, Comm 0.00
# 2023-02-22, OPERATION PROFIT, GROSS 7797.17, NET 7797.17
# 2023-05-30, (MA Period 20) Ending Value 114960.07
# Start Portfolio value: 100000.00
# Final Portfolio Value: 114960.07
# Profit: 14960.07
#
# META
# Starting Portfolio Value: 100000.00
# 2018-05-30, Previous Sentiment -0.60, New Sentiment 0.00 BUY CREATE, 187.67
# 2018-05-31, BUY EXECUTED, Price: 187.87, Cost: 18787.00, Comm 0.00
# 2018-07-26, Previous Sentiment 0.74, New Sentiment 0.21 SELL CREATE, 176.26
# 2018-07-27, SELL EXECUTED, Price: 179.87, Cost: 18787.00, Comm 0.00
# 2018-07-27, OPERATION PROFIT, GROSS -800.00, NET -800.00
# 2018-09-27, Previous Sentiment 0.11, New Sentiment 0.64 BUY CREATE, 168.84
# 2018-09-28, BUY EXECUTED, Price: 168.33, Cost: 16833.00, Comm 0.00
# 2018-09-28, Previous Sentiment 0.64, New Sentiment -0.11 SELL CREATE, 164.46
# 2018-10-01, SELL EXECUTED, Price: 163.03, Cost: 16833.00, Comm 0.00
# 2018-10-01, OPERATION PROFIT, GROSS -530.00, NET -530.00
# 2018-12-06, Previous Sentiment -0.01, New Sentiment 0.52 BUY CREATE, 139.63
# 2018-12-07, BUY EXECUTED, Price: 139.25, Cost: 13925.00, Comm 0.00
# 2018-12-27, Previous Sentiment 0.68, New Sentiment -0.09 SELL CREATE, 134.52
# 2018-12-28, SELL EXECUTED, Price: 135.34, Cost: 13925.00, Comm 0.00
# 2018-12-28, OPERATION PROFIT, GROSS -391.00, NET -391.00
# 2019-01-15, Previous Sentiment -0.55, New Sentiment 0.07 BUY CREATE, 148.95
# 2019-01-16, BUY EXECUTED, Price: 149.00, Cost: 14900.00, Comm 0.00
# 2019-03-28, Previous Sentiment 0.43, New Sentiment -0.24 SELL CREATE, 165.55
# 2019-03-29, SELL EXECUTED, Price: 166.39, Cost: 14900.00, Comm 0.00
# 2019-03-29, OPERATION PROFIT, GROSS 1739.00, NET 1739.00
# 2019-04-12, Previous Sentiment -0.72, New Sentiment -0.06 BUY CREATE, 179.10
# 2019-04-15, BUY EXECUTED, Price: 178.50, Cost: 17850.00, Comm 0.00
# 2019-08-06, Previous Sentiment 0.10, New Sentiment -0.46 SELL CREATE, 184.51
# 2019-08-07, SELL EXECUTED, Price: 183.60, Cost: 17850.00, Comm 0.00
# 2019-08-07, OPERATION PROFIT, GROSS 510.00, NET 510.00
# 2019-09-06, Previous Sentiment -0.27, New Sentiment 0.37 BUY CREATE, 187.49
# 2019-09-09, BUY EXECUTED, Price: 187.73, Cost: 18773.00, Comm 0.00
# 2019-10-03, Previous Sentiment 0.53, New Sentiment -0.13 SELL CREATE, 179.38
# 2019-10-04, SELL EXECUTED, Price: 179.55, Cost: 18773.00, Comm 0.00
# 2019-10-04, OPERATION PROFIT, GROSS -818.00, NET -818.00
# 2019-10-28, Previous Sentiment -0.02, New Sentiment 0.66 BUY CREATE, 189.40
# 2019-10-29, BUY EXECUTED, Price: 191.69, Cost: 19169.00, Comm 0.00
# 2019-12-12, Previous Sentiment 0.75, New Sentiment -0.21 SELL CREATE, 196.75
# 2019-12-13, SELL EXECUTED, Price: 196.40, Cost: 19169.00, Comm 0.00
# 2019-12-13, OPERATION PROFIT, GROSS 471.00, NET 471.00
# 2019-12-30, Previous Sentiment -0.50, New Sentiment 0.46 BUY CREATE, 204.41
# 2019-12-31, BUY EXECUTED, Price: 204.00, Cost: 20400.00, Comm 0.00
# 2020-01-31, Previous Sentiment 0.33, New Sentiment -0.36 SELL CREATE, 201.91
# 2020-02-03, SELL EXECUTED, Price: 203.44, Cost: 20400.00, Comm 0.00
# 2020-02-03, OPERATION PROFIT, GROSS -56.00, NET -56.00
# 2020-02-14, Previous Sentiment -0.01, New Sentiment 0.60 BUY CREATE, 214.18
# 2020-02-18, BUY EXECUTED, Price: 213.55, Cost: 21355.00, Comm 0.00
# 2020-03-02, Previous Sentiment 0.63, New Sentiment 0.11 SELL CREATE, 196.44
# 2020-03-03, SELL EXECUTED, Price: 196.22, Cost: 21355.00, Comm 0.00
# 2020-03-03, OPERATION PROFIT, GROSS -1733.00, NET -1733.00
# 2020-04-06, Previous Sentiment 0.24, New Sentiment 0.81 BUY CREATE, 165.55
# 2020-04-07, BUY EXECUTED, Price: 171.79, Cost: 17179.00, Comm 0.00
# 2020-09-21, Previous Sentiment 0.32, New Sentiment -0.35 SELL CREATE, 248.15
# 2020-09-22, SELL EXECUTED, Price: 253.31, Cost: 17179.00, Comm 0.00
# 2020-09-22, OPERATION PROFIT, GROSS 8152.00, NET 8152.00
# 2020-10-08, Previous Sentiment -0.24, New Sentiment 0.37 BUY CREATE, 263.76
# 2020-10-09, BUY EXECUTED, Price: 264.52, Cost: 26452.00, Comm 0.00
# 2020-10-28, Previous Sentiment 0.57, New Sentiment -0.56 SELL CREATE, 267.67
# 2020-10-29, SELL EXECUTED, Price: 276.55, Cost: 26452.00, Comm 0.00
# 2020-10-29, OPERATION PROFIT, GROSS 1203.00, NET 1203.00
# 2020-10-29, Previous Sentiment -0.56, New Sentiment 0.25 BUY CREATE, 280.83
# 2020-10-30, BUY EXECUTED, Price: 274.50, Cost: 27450.00, Comm 0.00
# 2020-11-17, Previous Sentiment 0.51, New Sentiment -0.09 SELL CREATE, 275.00
# 2020-11-18, SELL EXECUTED, Price: 274.52, Cost: 27450.00, Comm 0.00
# 2020-11-18, OPERATION PROFIT, GROSS 2.00, NET 2.00
# 2020-11-27, Previous Sentiment -0.45, New Sentiment 0.17 BUY CREATE, 277.81
# 2020-11-30, BUY EXECUTED, Price: 276.03, Cost: 27603.00, Comm 0.00
# 2020-12-15, Previous Sentiment 0.35, New Sentiment -0.16 SELL CREATE, 275.55
# 2020-12-16, SELL EXECUTED, Price: 274.76, Cost: 27603.00, Comm 0.00
# 2020-12-16, OPERATION PROFIT, GROSS -127.00, NET -127.00
# 2021-03-29, Previous Sentiment -0.20, New Sentiment 0.64 BUY CREATE, 290.82
# 2021-03-30, BUY EXECUTED, Price: 289.83, Cost: 28983.00, Comm 0.00
# 2021-05-11, Previous Sentiment 0.16, New Sentiment -0.37 SELL CREATE, 306.53
# 2021-05-12, SELL EXECUTED, Price: 301.13, Cost: 28983.00, Comm 0.00
# 2021-05-12, OPERATION PROFIT, GROSS 1130.00, NET 1130.00
# 2021-06-16, Previous Sentiment -0.34, New Sentiment 0.22 BUY CREATE, 331.08
# 2021-06-17, BUY EXECUTED, Price: 330.49, Cost: 33049.00, Comm 0.00
# 2021-07-19, Previous Sentiment 0.37, New Sentiment -0.21 SELL CREATE, 336.95
# 2021-07-20, SELL EXECUTED, Price: 338.80, Cost: 33049.00, Comm 0.00
# 2021-07-20, OPERATION PROFIT, GROSS 831.00, NET 831.00
# 2021-07-23, Previous Sentiment -0.33, New Sentiment 0.62 BUY CREATE, 369.79
# 2021-07-26, BUY EXECUTED, Price: 369.58, Cost: 36958.00, Comm 0.00
# 2021-08-18, Previous Sentiment 0.62, New Sentiment 0.11 SELL CREATE, 355.45
# 2021-08-19, SELL EXECUTED, Price: 351.35, Cost: 36958.00, Comm 0.00
# 2021-08-19, OPERATION PROFIT, GROSS -1823.00, NET -1823.00
# 2021-11-02, Previous Sentiment -0.07, New Sentiment 0.80 BUY CREATE, 328.08
# 2021-11-03, BUY EXECUTED, Price: 327.49, Cost: 32749.00, Comm 0.00
# 2022-01-06, Previous Sentiment 0.14, New Sentiment -0.39 SELL CREATE, 332.46
# 2022-01-07, SELL EXECUTED, Price: 332.74, Cost: 32749.00, Comm 0.00
# 2022-01-07, OPERATION PROFIT, GROSS 525.00, NET 525.00
# 2022-03-24, Previous Sentiment -0.37, New Sentiment 0.34 BUY CREATE, 219.57
# 2022-03-25, BUY EXECUTED, Price: 220.51, Cost: 22051.00, Comm 0.00
# 2022-04-27, Previous Sentiment -0.03, New Sentiment -0.65 SELL CREATE, 174.95
# 2022-04-28, SELL EXECUTED, Price: 202.92, Cost: 22051.00, Comm 0.00
# 2022-04-28, OPERATION PROFIT, GROSS -1759.00, NET -1759.00
# 2022-07-08, Previous Sentiment -0.63, New Sentiment 0.51 BUY CREATE, 170.88
# 2022-07-11, BUY EXECUTED, Price: 167.07, Cost: 16707.00, Comm 0.00
# 2022-07-11, Previous Sentiment 0.51, New Sentiment -0.30 SELL CREATE, 162.88
# 2022-07-12, SELL EXECUTED, Price: 164.80, Cost: 16707.00, Comm 0.00
# 2022-07-12, OPERATION PROFIT, GROSS -227.00, NET -227.00
# 2022-08-05, Previous Sentiment -0.25, New Sentiment 0.29 BUY CREATE, 167.11
# 2022-08-08, BUY EXECUTED, Price: 168.00, Cost: 16800.00, Comm 0.00
# 2022-08-25, Previous Sentiment 0.29, New Sentiment -0.40 SELL CREATE, 168.78
# 2022-08-26, SELL EXECUTED, Price: 168.48, Cost: 16800.00, Comm 0.00
# 2022-08-26, OPERATION PROFIT, GROSS 48.00, NET 48.00
# 2022-11-11, Previous Sentiment -0.52, New Sentiment 0.03 BUY CREATE, 113.02
# 2022-11-14, BUY EXECUTED, Price: 110.99, Cost: 11099.00, Comm 0.00
# 2022-12-19, Previous Sentiment 0.74, New Sentiment -0.49 SELL CREATE, 114.48
# 2022-12-20, SELL EXECUTED, Price: 113.26, Cost: 11099.00, Comm 0.00
# 2022-12-20, OPERATION PROFIT, GROSS 227.00, NET 227.00
# 2022-12-20, Previous Sentiment -0.49, New Sentiment 0.13 BUY CREATE, 117.09
# 2022-12-21, BUY EXECUTED, Price: 116.70, Cost: 11670.00, Comm 0.00
# 2023-05-30, (MA Period 20) Ending Value 121156.00
# Start Portfolio value: 100000.00
# Final Portfolio Value: 121156.00
# Profit: 21156.00
#
# TSLA
# Starting Portfolio Value: 100000.00
# 2018-04-13, Previous Sentiment 0.03, New Sentiment 0.69 BUY CREATE, 20.02
# 2018-04-16, BUY EXECUTED, Price: 19.93, Cost: 1993.33, Comm 0.00
# 2018-07-11, Previous Sentiment 0.21, New Sentiment -0.32 SELL CREATE, 21.26
# 2018-07-12, SELL EXECUTED, Price: 21.43, Cost: 1993.33, Comm 0.00
# 2018-07-12, OPERATION PROFIT, GROSS 149.53, NET 149.53
# 2018-09-25, Previous Sentiment -0.14, New Sentiment 0.38 BUY CREATE, 20.07
# 2018-09-26, BUY EXECUTED, Price: 20.13, Cost: 2012.73, Comm 0.00
# 2018-10-08, Previous Sentiment -0.05, New Sentiment -0.63 SELL CREATE, 16.70
# 2018-10-09, SELL EXECUTED, Price: 17.02, Cost: 2012.73, Comm 0.00
# 2018-10-09, OPERATION PROFIT, GROSS -311.07, NET -311.07
# 2019-01-10, Previous Sentiment -0.63, New Sentiment -0.02 BUY CREATE, 23.00
# 2019-01-11, BUY EXECUTED, Price: 22.81, Cost: 2280.60, Comm 0.00
# 2019-02-20, Previous Sentiment 0.63, New Sentiment 0.03 SELL CREATE, 20.17
# 2019-02-21, SELL EXECUTED, Price: 20.12, Cost: 2280.60, Comm 0.00
# 2019-02-21, OPERATION PROFIT, GROSS -268.53, NET -268.53
# 2019-06-17, Previous Sentiment -0.36, New Sentiment 0.39 BUY CREATE, 15.00
# 2019-06-18, BUY EXECUTED, Price: 15.25, Cost: 1524.80, Comm 0.00
# 2019-08-05, Previous Sentiment 0.35, New Sentiment -0.28 SELL CREATE, 15.22
# 2019-08-06, SELL EXECUTED, Price: 15.46, Cost: 1524.80, Comm 0.00
# 2019-08-06, OPERATION PROFIT, GROSS 21.07, NET 21.07
# 2019-09-19, Previous Sentiment -0.22, New Sentiment 0.54 BUY CREATE, 16.44
# 2019-09-20, BUY EXECUTED, Price: 16.43, Cost: 1643.27, Comm 0.00
# 2020-02-27, Previous Sentiment 0.50, New Sentiment -0.22 SELL CREATE, 45.27
# 2020-02-28, SELL EXECUTED, Price: 41.98, Cost: 1643.27, Comm 0.00
# 2020-02-28, OPERATION PROFIT, GROSS 2554.73, NET 2554.73
# 2020-04-23, Previous Sentiment -0.10, New Sentiment 0.60 BUY CREATE, 47.04
# 2020-04-24, BUY EXECUTED, Price: 47.39, Cost: 4738.73, Comm 0.00
# 2020-10-27, Previous Sentiment 0.05, New Sentiment -0.58 SELL CREATE, 141.56
# 2020-10-28, SELL EXECUTED, Price: 138.83, Cost: 4738.73, Comm 0.00
# 2020-10-28, OPERATION PROFIT, GROSS 9143.93, NET 9143.93
# 2020-11-30, Previous Sentiment -0.31, New Sentiment 0.83 BUY CREATE, 189.20
# 2020-12-01, BUY EXECUTED, Price: 199.20, Cost: 19919.67, Comm 0.00
# 2021-02-18, Previous Sentiment 0.44, New Sentiment -0.25 SELL CREATE, 262.46
# 2021-02-19, SELL EXECUTED, Price: 265.00, Cost: 19919.67, Comm 0.00
# 2021-02-19, OPERATION PROFIT, GROSS 6580.33, NET 6580.33
# 2021-04-01, Previous Sentiment 0.05, New Sentiment 0.81 BUY CREATE, 220.58
# 2021-04-05, BUY EXECUTED, Price: 235.90, Cost: 23590.33, Comm 0.00
# 2021-05-11, Previous Sentiment 0.76, New Sentiment 0.21 SELL CREATE, 205.73
# 2021-05-12, SELL EXECUTED, Price: 200.83, Cost: 23590.33, Comm 0.00
# 2021-05-12, OPERATION PROFIT, GROSS -3507.33, NET -3507.33
# 2021-06-01, Previous Sentiment 0.03, New Sentiment 0.66 BUY CREATE, 207.97
# 2021-06-02, BUY EXECUTED, Price: 206.71, Cost: 20671.00, Comm 0.00
# 2021-07-14, Previous Sentiment 0.61, New Sentiment 0.04 SELL CREATE, 217.79
# 2021-07-15, SELL EXECUTED, Price: 219.46, Cost: 20671.00, Comm 0.00
# 2021-07-15, OPERATION PROFIT, GROSS 1275.33, NET 1275.33
# 2021-08-13, Previous Sentiment -0.11, New Sentiment 0.56 BUY CREATE, 239.06
# 2021-08-16, BUY EXECUTED, Price: 235.02, Cost: 23502.33, Comm 0.00
# 2021-11-15, Previous Sentiment 0.55, New Sentiment -0.09 SELL CREATE, 337.80
# 2021-11-16, SELL EXECUTED, Price: 334.44, Cost: 23502.33, Comm 0.00
# 2021-11-16, OPERATION PROFIT, GROSS 9941.33, NET 9941.33
# 2022-03-25, Previous Sentiment -0.27, New Sentiment 0.37 BUY CREATE, 336.88
# 2022-03-28, BUY EXECUTED, Price: 355.03, Cost: 35503.33, Comm 0.00
# 2022-05-09, Previous Sentiment 0.16, New Sentiment -0.46 SELL CREATE, 262.37
# 2022-05-10, SELL EXECUTED, Price: 273.10, Cost: 35503.33, Comm 0.00
# 2022-05-10, OPERATION PROFIT, GROSS -8193.00, NET -8193.00
# 2022-06-08, Previous Sentiment 0.06, New Sentiment 0.61 BUY CREATE, 241.87
# 2022-06-09, BUY EXECUTED, Price: 249.34, Cost: 24934.00, Comm 0.00
# 2022-06-10, Previous Sentiment 0.58, New Sentiment -0.02 SELL CREATE, 232.23
# 2022-06-13, SELL EXECUTED, Price: 223.17, Cost: 24934.00, Comm 0.00
# 2022-06-13, OPERATION PROFIT, GROSS -2617.33, NET -2617.33
# 2022-06-22, Previous Sentiment -0.05, New Sentiment 0.53 BUY CREATE, 236.09
# 2022-06-23, BUY EXECUTED, Price: 237.91, Cost: 23790.67, Comm 0.00
# 2022-09-02, Previous Sentiment 0.69, New Sentiment 0.08 SELL CREATE, 270.21
# 2022-09-06, SELL EXECUTED, Price: 272.68, Cost: 23790.67, Comm 0.00
# 2022-09-06, OPERATION PROFIT, GROSS 3477.33, NET 3477.33
# 2022-09-16, Previous Sentiment 0.08, New Sentiment 0.74 BUY CREATE, 303.35
# 2022-09-19, BUY EXECUTED, Price: 300.09, Cost: 30009.00, Comm 0.00
# 2022-10-03, Previous Sentiment 0.56, New Sentiment -0.18 SELL CREATE, 242.40
# 2022-10-04, SELL EXECUTED, Price: 250.52, Cost: 30009.00, Comm 0.00
# 2022-10-04, OPERATION PROFIT, GROSS -4957.00, NET -4957.00
# 2023-01-25, Previous Sentiment -0.15, New Sentiment 0.40 BUY CREATE, 144.43
# 2023-01-26, BUY EXECUTED, Price: 159.97, Cost: 15997.00, Comm 0.00
# 2023-03-06, Previous Sentiment 0.43, New Sentiment -0.18 SELL CREATE, 193.81
# 2023-03-07, SELL EXECUTED, Price: 191.38, Cost: 15997.00, Comm 0.00
# 2023-03-07, OPERATION PROFIT, GROSS 3141.00, NET 3141.00
# 2023-03-21, Previous Sentiment -0.60, New Sentiment 0.30 BUY CREATE, 197.58
# 2023-03-22, BUY EXECUTED, Price: 199.30, Cost: 19930.00, Comm 0.00
# 2023-04-05, Previous Sentiment 0.60, New Sentiment -0.01 SELL CREATE, 185.52
# 2023-04-06, SELL EXECUTED, Price: 183.08, Cost: 19930.00, Comm 0.00
# 2023-04-06, OPERATION PROFIT, GROSS -1622.00, NET -1622.00
# 2023-05-11, Previous Sentiment -0.05, New Sentiment 0.73 BUY CREATE, 172.08
# 2023-05-12, BUY EXECUTED, Price: 176.07, Cost: 17607.00, Comm 0.00
# 2023-05-30, (MA Period 20) Ending Value 117317.33
# Start Portfolio value: 100000.00
# Final Portfolio Value: 117317.33
# Profit: 17317.33
#
# PEP
# Starting Portfolio Value: 100000.00
# 2020-06-23, Previous Sentiment -0.15, New Sentiment 0.40 BUY CREATE, 120.88
# 2020-06-24, BUY EXECUTED, Price: 120.10, Cost: 12010.49, Comm 0.00
# 2021-01-06, Previous Sentiment 0.37, New Sentiment -0.41 SELL CREATE, 133.41
# 2021-01-07, SELL EXECUTED, Price: 133.30, Cost: 12010.49, Comm 0.00
# 2021-01-07, OPERATION PROFIT, GROSS 1319.72, NET 1319.72
# 2021-04-12, Previous Sentiment -0.09, New Sentiment 0.64 BUY CREATE, 134.56
# 2021-04-13, BUY EXECUTED, Price: 133.67, Cost: 13367.02, Comm 0.00
# 2022-03-01, Previous Sentiment 0.73, New Sentiment 0.17 SELL CREATE, 155.89
# 2022-03-02, SELL EXECUTED, Price: 156.57, Cost: 13367.02, Comm 0.00
# 2022-03-02, OPERATION PROFIT, GROSS 2290.37, NET 2290.37
# 2022-03-23, Previous Sentiment -0.06, New Sentiment 0.55 BUY CREATE, 158.09
# 2022-03-24, BUY EXECUTED, Price: 158.65, Cost: 15864.81, Comm 0.00
# 2022-09-20, Previous Sentiment 0.66, New Sentiment 0.12 SELL CREATE, 165.59
# 2022-09-21, SELL EXECUTED, Price: 166.53, Cost: 15864.81, Comm 0.00
# 2022-09-21, OPERATION PROFIT, GROSS 788.23, NET 788.23
# 2022-10-12, Previous Sentiment -0.04, New Sentiment 0.55 BUY CREATE, 166.05
# 2022-10-13, BUY EXECUTED, Price: 163.81, Cost: 16380.52, Comm 0.00
# 2023-05-30, (MA Period 20) Ending Value 106052.81
# Start Portfolio value: 100000.00
# Final Portfolio Value: 106052.81
# Profit: 6052.81
#
# AVGO
# Starting Portfolio Value: 100000.00
# 2018-03-07, Previous Sentiment -0.25, New Sentiment 0.37 BUY CREATE, 203.03
# 2018-03-08, BUY EXECUTED, Price: 204.02, Cost: 20402.03, Comm 0.00
# 2018-10-10, Previous Sentiment -0.06, New Sentiment -0.67 SELL CREATE, 197.37
# 2018-10-11, SELL EXECUTED, Price: 197.49, Cost: 20402.03, Comm 0.00
# 2018-10-11, OPERATION PROFIT, GROSS -652.82, NET -652.82
# 2019-02-19, Previous Sentiment -0.40, New Sentiment 0.17 BUY CREATE, 242.32
# 2019-02-20, BUY EXECUTED, Price: 243.69, Cost: 24369.15, Comm 0.00
# 2019-08-15, Previous Sentiment 0.43, New Sentiment -0.33 SELL CREATE, 235.42
# 2019-08-16, SELL EXECUTED, Price: 238.50, Cost: 24369.15, Comm 0.00
# 2019-08-16, OPERATION PROFIT, GROSS -519.34, NET -519.34
# 2020-04-22, Previous Sentiment -0.28, New Sentiment 0.27 BUY CREATE, 236.20
# 2020-04-23, BUY EXECUTED, Price: 236.45, Cost: 23645.17, Comm 0.00
# 2021-09-28, Previous Sentiment 0.71, New Sentiment 0.01 SELL CREATE, 469.32
# 2021-09-29, SELL EXECUTED, Price: 471.81, Cost: 23645.17, Comm 0.00
# 2021-09-29, OPERATION PROFIT, GROSS 23536.14, NET 23536.14
# 2021-12-10, Previous Sentiment 0.04, New Sentiment 0.85 BUY CREATE, 603.76
# 2021-12-13, BUY EXECUTED, Price: 605.98, Cost: 60597.93, Comm 0.00
# 2022-07-05, Previous Sentiment 0.62, New Sentiment -0.34 SELL CREATE, 465.08
# 2022-07-06, SELL EXECUTED, Price: 469.21, Cost: 60597.93, Comm 0.00
# 2022-07-06, OPERATION PROFIT, GROSS -13676.55, NET -13676.55
# 2022-12-06, Previous Sentiment -0.13, New Sentiment 0.64 BUY CREATE, 517.74
# 2022-12-07, BUY EXECUTED, Price: 511.62, Cost: 51161.81, Comm 0.00
# 2022-12-07, Previous Sentiment 0.64, New Sentiment 0.12 SELL CREATE, 510.53
# 2022-12-08, SELL EXECUTED, Price: 512.81, Cost: 51161.81, Comm 0.00
# 2022-12-08, OPERATION PROFIT, GROSS 119.14, NET 119.14
# 2023-01-26, Previous Sentiment 0.05, New Sentiment 0.67 BUY CREATE, 594.30
# 2023-01-27, BUY EXECUTED, Price: 589.08, Cost: 58908.01, Comm 0.00
# 2023-05-30, (MA Period 20) Ending Value 130232.58
# Start Portfolio value: 100000.00
# Final Portfolio Value: 130232.58
# Profit: 30232.58
#
# ASML
# Starting Portfolio Value: 100000.00
# 2018-11-30, Previous Sentiment -0.42, New Sentiment 0.10 BUY CREATE, 163.28
# 2018-12-03, BUY EXECUTED, Price: 165.67, Cost: 16566.85, Comm 0.00
# 2021-03-03, Previous Sentiment 0.34, New Sentiment -0.26 SELL CREATE, 531.04
# 2021-03-04, SELL EXECUTED, Price: 525.43, Cost: 16566.85, Comm 0.00
# 2021-03-04, OPERATION PROFIT, GROSS 35975.91, NET 35975.91
# 2023-05-30, (MA Period 20) Ending Value 135975.91
# Start Portfolio value: 100000.00
# Final Portfolio Value: 135975.91
# Profit: 35975.91

# %%
pd.DataFrame.from_dict(all_tickers).set_index([pd.Index(["Start Price", 'Profit'])])
# Out:
#                      AAPL          MSFT        GOOGL        AMZN  \
# Start Price     40.831589     80.562050    53.660500   59.450500
# Profit       12139.738383  19699.039273  8496.899033  523.648834
#
#                      NVDA          META          TSLA          PEP  \
# Start Price     49.321175    181.419998     21.368668   100.651840
# Profit       14960.074048  21156.002808  17317.334938  6052.809165
#
#                      AVGO          ASML
# Start Price    219.429108    167.869263
# Profit       30232.579902  35975.911609

# %%
import torch

torch.cuda.is_available()
# Out:
# False
